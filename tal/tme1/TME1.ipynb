# %% [markdown]
# ## TME 1 TAL

# %%
import nltk
nltk.download()
# Out:
# showing info http://www.nltk.org/nltk_data/
# True

# %%
# -*- coding: utf-8 -*-
import io
text = io.open('test_srt.txt','rU', encoding='utf-8')
text = text.read()
tokens = nltk.word_tokenize(text)

tagged = nltk.pos_tag(tokens)
print tagged
# Out:
# [(u'Do', 'NNP'), (u'you', 'PRP'), (u'want', 'VB'), (u'me', 'PRP'), (u'to', 'TO'), (u'sit', 'VB'), (u'here', 'RB'), (u'?', '.'), (u'No', 'DT'), (u',', ','), (u'here', 'RB'), (u'is', 'VBZ'), (u'fine', 'NN'), (u'.', '.'), (u'-', ':'), (u'You', 'PRP'), (u"'re", 'VBP'), (u'Kristen', 'NNP'), (u'Balko', 'NNP'), (u'?', '.'), (u'-', ':'), (u'Yes', 'NNP'), (u'.', '.'), (u'And', 'CC'), (u'you', 'PRP'), (u"'re", 'VBP'), (u'VP', 'NNP'), (u'of', 'IN'), (u'Information', 'NNP'), (u'Security', 'NNP'), (u'at', 'IN'), (u'Running', 'NNP'), (u'Milk', 'NNP'), (u'?', '.'), (u'That', 'DT'), (u"'s", 'VBZ'), (u'right', 'RB'), (u'.', '.'), (u'Um', 'NNP'), (u',', ','), (u'is', 'VBZ'), (u'this', 'DT'), (u'part', 'NN'), (u'of', 'IN'), (u'the', 'DT'), (u'test', 'NN'), (u'?', '.'), (u'No', 'DT'), (u',', ','), (u'just', 'RB'), (u'the', 'DT'), (u'pre-test', 'JJ'), (u'.', '.'), (u'Think', 'NNP'), (u'of', 'IN'), (u'this', 'DT'), (u'as', 'IN'), (u'a', 'DT'), (u'practice', 'NN'), (u'run', 'VBN'), (u'.', '.'), (u'We', 'PRP'), (u'gather', 'RB'), (u'some', 'DT'), (u'background', 'NN'), (u'information', 'NN'), (u',', ','), (u'then', 'RB'), (u'go', 'VB'), (u'over', 'IN'), (u'the', 'DT'), (u'questions', 'NNS'), (u'you', 'PRP'), (u"'ll", 'MD'), (u'be', 'VB'), (u'asked', 'VBN'), (u'.', '.'), (u'You', 'PRP'), (u"'re", 'VBP'), (u'gon', 'JJ'), (u'na', 'NN'), (u'tell', 'NN'), (u'me', 'PRP'), (u'the', 'DT'), (u'questions', 'NNS'), (u'on', 'IN'), (u'the', 'DT'), (u'test', 'NN'), (u'-', ':'), (u'before', 'IN'), (u'the', 'DT'), (u'test', 'NN'), (u'?', '.'), (u'-', ':'), (u'That', 'DT'), (u"'s", 'VBZ'), (u'right', 'RB'), (u'.', '.'), (u'Is', 'VBZ'), (u"n't", 'RB'), (u'that', 'IN'), (u'cheating', 'NN'), (u'?', '.'), (u'Uh', 'NNP'), (u',', ','), (u'no', 'DT'), (u',', ','), (u'it', 'PRP'), (u'is', 'VBZ'), (u"n't", 'RB'), (u'like', 'IN'), (u'the', 'DT'), (u'movies', 'NNS'), (u',', ','), (u'Ms.', 'NNP'), (u'Balko', 'NNP'), (u'.', '.'), (u'There', 'EX'), (u'are', 'VBP'), (u'no', 'DT'), (u'``', '``'), (u'gotcha', 'NN'), (u'moments', 'NNS'), (u"''", "''"), (u'.', '.'), (u'You', 'PRP'), (u"'ll", 'MD'), (u'know', 'VB'), (u'every', 'DT'), (u'question', 'NN'), (u'beforehand', 'NN'), (u'.', '.'), (u'Okay', 'NNP'), (u',', ','), (u'got', 'VBD'), (u'it', 'PRP'), (u'.', '.'), (u'Fire', 'NNP'), (u'away', 'RB'), (u'.', '.'), (u'Have', 'NNP'), (u'you', 'PRP'), (u'ever', 'RB'), (u'shared', 'VBN'), (u'confidential', 'JJ'), (u'materials', 'NNS'), (u'with', 'IN'), (u'individuals', 'NNS'), (u'not', 'RB'), (u'employed', 'VBN'), (u'with', 'IN'), (u'Running', 'NNP'), (u'Milk', 'NNP'), (u'?', '.'), (u'No', 'DT'), (u',', ','), (u'never', 'RB'), (u'.', '.'), (u'Am', 'NNP'), (u'I', 'PRP'), (u'supposed', 'VBD'), (u'to', 'TO'), (u'answer', 'VB'), (u'?', '.'), (u'Anything', 'NNP'), (u'you', 'PRP'), (u'want', 'VBP'), (u'.', '.'), (u'Have', 'NNP'), (u'you', 'PRP'), (u'ever', 'RB'), (u'stolen', 'VBN'), (u'anything', 'NN'), (u'from', 'IN'), (u'your', 'PRP$'), (u'workplace', 'NN'), (u'?', '.'), (u'Never', 'NNP'), (u'.', '.'), (u'Have', 'NNP'), (u'you', 'PRP'), (u'ever', 'RB'), (u'lied', 'VBN'), (u'to', 'TO'), (u'the', 'DT'), (u'company', 'NN'), (u'?', '.'), (u'No', 'NNP'), (u'.', '.'), (u'I', 'PRP'), (u'lied', 'VBD'), (u'.', '.'), (u'You', 'PRP'), (u'did', 'VBD'), (u'steal', 'JJ'), (u'materials', 'NNS'), (u'from', 'IN'), (u'the', 'DT'), (u'workplace', 'NN'), (u'?', '.'), (u'No', 'DT'), (u',', ','), (u'I', 'PRP'), (u'lied', 'VBD'), (u'by', 'IN'), (u'saying', 'VBG'), (u'I', 'PRP'), (u'never', 'RB'), (u'lied', 'VBD'), (u'to', 'TO'), (u'the', 'DT'), (u'company', 'NN'), (u'.', '.'), (u'Could', 'MD'), (u'you', 'PRP'), (u'be', 'VB'), (u'more', 'RBR'), (u'specific', 'JJ'), (u'?', '.'), (u'When', 'WRB'), (u'I', 'PRP'), (u'applied', 'VBD'), (u',', ','), (u'in', 'IN'), (u'my', 'PRP$'), (u'r\xe9sum\xe9', 'NN'), (u'I', 'PRP'), (u'told', 'VBD'), (u'them', 'PRP'), (u'that', 'IN'), (u'I', 'PRP'), (u'worked', 'VBD'), (u'as', 'IN'), (u'a', 'DT'), (u'VP', 'NNP'), (u'of', 'IN'), (u'Information', 'NNP'), (u'Technology', 'NNP'), (u'at', 'IN' ...

# %%
entities = nltk.chunk.ne_chunk(tagged)
print entities
# Out:
# (S
#   Do/NNP
#   you/PRP
#   want/VB
#   me/PRP
#   to/TO
#   sit/VB
#   here/RB
#   ?/.
#   No/DT
#   ,/,
#   here/RB
#   is/VBZ
#   fine/NN
#   ./.
#   -/:
#   You/PRP
#   're/VBP
#   (PERSON Kristen/NNP Balko/NNP)
#   ?/.
#   -/:
#   Yes/NNP
#   ./.
#   And/CC
#   you/PRP
#   're/VBP
#   VP/NNP
#   of/IN
#   (ORGANIZATION Information/NNP)
#   Security/NNP
#   at/IN
#   (FACILITY Running/NNP Milk/NNP)
#   ?/.
#   That/DT
#   's/VBZ
#   right/RB
#   ./.
#   Um/NNP
#   ,/,
#   is/VBZ
#   this/DT
#   part/NN
#   of/IN
#   the/DT
#   test/NN
#   ?/.
#   No/DT
#   ,/,
#   just/RB
#   the/DT
#   pre-test/JJ
#   ./.
#   Think/NNP
#   of/IN
#   this/DT
#   as/IN
#   a/DT
#   practice/NN
#   run/VBN
#   ./.
#   We/PRP
#   gather/RB
#   some/DT
#   background/NN
#   information/NN
#   ,/,
#   then/RB
#   go/VB
#   over/IN
#   the/DT
#   questions/NNS
#   you/PRP
#   'll/MD
#   be/VB
#   asked/VBN
#   ./.
#   You/PRP
#   're/VBP
#   gon/JJ
#   na/NN
#   tell/NN
#   me/PRP
#   the/DT
#   questions/NNS
#   on/IN
#   the/DT
#   test/NN
#   -/:
#   before/IN
#   the/DT
#   test/NN
#   ?/.
#   -/:
#   That/DT
#   's/VBZ
#   right/RB
#   ./.
#   Is/VBZ
#   n't/RB
#   that/IN
#   cheating/NN
#   ?/.
#   Uh/NNP
#   ,/,
#   no/DT
#   ,/,
#   it/PRP
#   is/VBZ
#   n't/RB
#   like/IN
#   the/DT
#   movies/NNS
#   ,/,
#   Ms./NNP
#   Balko/NNP
#   ./.
#   There/EX
#   are/VBP
#   no/DT
#   ``/``
#   gotcha/NN
#   moments/NNS
#   ''/''
#   ./.
#   You/PRP
#   'll/MD
#   know/VB
#   every/DT
#   question/NN
#   beforehand/NN
#   ./.
#   (PERSON Okay/NNP)
#   ,/,
#   got/VBD
#   it/PRP
#   ./.
#   (PERSON Fire/NNP)
#   away/RB
#   ./.
#   Have/NNP
#   you/PRP
#   ever/RB
#   shared/VBN
#   confidential/JJ
#   materials/NNS
#   with/IN
#   individuals/NNS
#   not/RB
#   employed/VBN
#   with/IN
#   (PERSON Running/NNP Milk/NNP)
#   ?/.
#   No/DT
#   ,/,
#   never/RB
#   ./.
#   Am/NNP
#   I/PRP
#   supposed/VBD
#   to/TO
#   answer/VB
#   ?/.
#   Anything/NNP
#   you/PRP
#   want/VBP
#   ./.
#   Have/NNP
#   you/PRP
#   ever/RB
#   stolen/VBN
#   anything/NN
#   from/IN
#   your/PRP$
#   workplace/NN
#   ?/.
#   Never/NNP
#   ./.
#   Have/NNP
#   you/PRP
#   ever/RB
#   lied/VBN
#   to/TO
#   the/DT
#   company/NN
#   ?/.
#   No/NNP
#   ./.
#   I/PRP
#   lied/VBD
#   ./.
#   You/PRP
#   did/VBD
#   steal/JJ
#   materials/NNS
#   from/IN
#   the/DT
#   workplace/NN
#   ?/.
#   No/DT
#   ,/,
#   I/PRP
#   lied/VBD
#   by/IN
#   saying/VBG
#   I/PRP
#   never/RB
#   lied/VBD
#   to/TO
#   the/DT
#   company/NN
#   ./.
#   Could/MD
#   you/PRP
#   be/VB
#   more/RBR
#   specific/JJ
#   ?/.
#   When/WRB
#   I/PRP
#   applied/VBD
#   ,/,
#   in/IN
#   my/PRP$
#   resume/NN
#   I/PRP
#   told/VBD
#   them/PRP
#   that/IN
#   I/PRP
#   worked/VBD
#   as/IN
#   a/DT
#   VP/NNP
#   of/IN
#   (ORGANIZATION Information/NNP Technology/NNP)
#   at/IN
#   a/DT
#   previous/JJ
#   company/NN
#   ./.
#   But/CC
#   there/EX
#   was/VBD
#   no/DT
#   VP/NNP
#   of/IN
#   (ORGANIZATION Information/NNP Technology/NNP)
#   ./.
#   -/:
#   (GPE Oh/NNP)
#   ,/,
#   that/IN
#   's/POS
#   it/PRP
#   ?/.
#   -/:
#   (GPE Yes/NNP)
#   ,/,
#   what/WP
#   do/VBP
#   you/PRP
#   mean/VB
#   ?/.
#   They/PRP
#   fired/VBD
#   you/PRP
#   because/IN
#   you/PRP
#   said/VBD
#   you/PRP
#   were/VBD
#   a/DT
#   VP/NNP
#   on/IN
#   your/PRP$
#   resume/NN
#   ?/.
#   No/DT
#   ,/,
#   they/PRP
#   fired/VBD
#   me/PRP
#   because/IN
#   I/PRP
#   lied/VBD
#   in/IN
#   the/DT
#   lie/NN
#   detector/NN
#   test/NN
#   ./.
#   But/CC
#   that/IN
#   was/VBD
#   n't/RB
#   the/DT
#   point/NN
#   of/IN
#   the/DT
#   lie/NN
#   detector/NN
#   test/NN
#   ,/,
#   right/RB
#   ?/.
#   They/PRP
#   were/VBD
#   trying/VBG
#   to/TO
#   find/VB
#   someone/NN
#   who/WP
#   stole/NN
#   -/:
#   confidential/JJ
#   materials/NNS
#   ./.
#   -/:
#   (GPE Right/NNP)
#   ./.
#   And/CC
#   you/PRP
#   did/VBD
#   n't/RB
#   do/VB
#   that/DT
#   ./.
#   Did/NNP
#   you/PRP
#   try/VBP
#   to/TO
#   explain/VB
#   that/IN
#   to/TO
#   your/PRP$
#   boss/NN
#   ?/.
#   Yes/NNP
#   ,/,
#   but/CC
#   they/PRP
#   said/VBD
#   I/PRP
#   lied/VBD
#   to/TO
#   the/DT
#   company/NN
#   ,/,
#   so/RB
#   they/PRP
#   could/MD
#   fire/VB
#   me/PRP
#   ./.
#   That/DT
#   's/VBZ
#   why/WRB
#   I/PRP
#   'm/VBP
#   suing/VBG
#   ./.
#   (PERSON Silicon/NNP Valley/NNP)
#   's/POS
#   a/DT
#   very/RB
#   provincial/JJ
#   town/NN
#   ./.
#   I/PRP
#   ca/MD
#   n't/RB
#   get/VB
#   a/DT
#   job/NN
#   anywhere/RB
#   ./.
#   Well/NNP
#   ,/,
#   (ORGANIZATION The/NNP Polygraph/NNP)
#   Protection/NNP
#   Act/NNP
#   keeps/VBZ
#   an/DT
#   employer/NN
#   from/IN
#   forcing/JJ
#   you/PRP
#   to/TO
#   take/VB
#   a/DT
#   lie/NN
#   detector/NN
#   test/NN
#   ,/,
#   but/CC
#   there/EX
#   are/VBP
#   exceptions/NNS
#   ./.
#   Theft/NNP
#   ./.
#   Uh/NNP
#   ,/,
#   (PERSON Kristen/NNP)
#   ,/,
#   this/DT
#   is/VBZ
#   our/PRP$
#   investigator/NN
#   (PERSON Jason/NNP)
#   ./.
#   Hi/NNP
#   ./.
#   But/CC
#   I/PRP
#   did/VBD
#   n't/RB
#   steal/VB
#   anything/NN
#   ./.
#   Yes/NNP
#   ,/,
#   but/CC
#   it/PRP
#   was/VBD
#   the/DT
#   reason/NN
#   for/IN
#   the/DT
#   polygraph/NN
#   ./.
#   They/PRP
#   caught/VBD
#   you/PRP
#   in/IN
#   another/DT
#   lie/NN
#   ,/,
#   but/CC
#   .../:
#   They/PRP
#   need/VBP
#   corroborating/VBG
#   evidence/NN
#   ./.
#   Right/NNP
#   ./.
#   And/CC
#   they/PRP
#   could/MD
#   n't/RB
#   have/VB
#   fired/VBN
#   her/PRP
#   unless/IN
#   they/PRP
#   already/RB
#   had/VBD
#   some/DT
#   evidence/NN
#   that/IN
#   she/PRP
#   lied/VBD
#   on/IN
#   her/PRP$
#   resume/NN
#   ./.
#   Did/NNP
#   they/PRP
#   ,/,
#   (PERSON Kristen/NNP)
#   ?/.
#   Have/NNP
#   evidence/NN
#   I/PRP
#   lied/VBD
#   ?/.
#   No/DT
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   think/VB
#   so/RB
#   ./.
#   The/DT
#   whole/JJ
#   point/NN
#   of/IN
#   the/DT
#   polygraph/NN
#   was/VBD
#   about/IN
#   this/DT
#   theft/NN
#   ./.
#   (PERSON Okay/NNP)
#   ,/,
#   um/NN
#   ,/,
#   why/WRB
#   do/VBP
#   n't/RB
#   you/PRP
#   give/VB
#   us/PRP
#   the/DT
#   day/NN
#   to/TO
#   think/VB
#   about/IN
#   it/PRP
#   ?/.
#   Actually/RB
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   have/VB
#   a/DT
#   day/NN
#   ./.
#   (PERSON Mr./NNP Canning/NNP)
#   told/VBD
#   me/PRP
#   you/PRP
#   'd/MD
#   be/VB
#   able/JJ
#   to/TO
#   move/VB
#   faster/JJR
#   than/IN
#   he/PRP
#   could/MD
#   ./.
#   -/:
#   (PERSON Louis/NNP Canning/NNP)
#   ?/.
#   -/:
#   Yes/NNP
#   ./.
#   He/PRP
#   already/RB
#   filed/VBN
#   the/DT
#   suit/NN
#   ,/,
#   but/CC
#   he/PRP
#   got/VBD
#   busy/JJ
#   with/IN
#   another/DT
#   case/NN
#   ,/,
#   and/CC
#   he/PRP
#   thought/VBD
#   you/PRP
#   'd/MD
#   be/VB
#   good/JJ
#   to/TO
#   take/VB
#   it/PRP
#   over/IN
#   ./.
#   I/PRP
#   'm/VBP
#   sure/JJ
#   he/PRP
#   did/VBD
#   ./.
#   All/DT
#   right/NN
#   ,/,
#   I/PRP
#   will/MD
#   see/VB
#   if/IN
#   they/PRP
#   have/VBP
#   any/DT
#   corroborating/VBG
#   evidence/NN
#   ./.
#   (PERSON Good/NNP)
#   ,/,
#   a/DT
#   polygraph/NN
#   ca/MD
#   n't/RB
#   be/VB
#   the/DT
#   sole/JJ
#   basis/NN
#   for/IN
#   firing/NN
#   ./.
#   So/RB
#   what/WP
#   .../:
#   cap/NN
#   my/PRP$
#   work/NN
#   off/RP
#   at/IN
#   five/CD
#   hours/NNS
#   ?/.
#   -/:
#   (GPE Yeah/NNP)
#   ./.
#   -/:
#   (GPE Okay/NNP)
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   did/VBD
#   you/PRP
#   find/VBP
#   out/RP
#   about/IN
#   insurance/NN
#   ?/.
#   Oh/NNP
#   ,/,
#   yeah/NN
#   ./.
#   Malpractice/NNP
#   insurance/NN
#   is/VBZ
#   a/DT
#   fortune/NN
#   ,/,
#   but/CC
#   we/PRP
#   could/MD
#   bundle/VB
#   it/PRP
#   ./.
#   I/PRP
#   can/MD
#   get/VB
#   a/DT
#   rider/NN
#   to/TO
#   your/PRP$
#   homeowner/NN
#   's/POS
#   policy/NN
#   ,/,
#   and/CC
#   just/RB
#   split/JJ
#   the/DT
#   increase/NN
#   in/IN
#   your/PRP$
#   premium/NN
#   ?/.
#   Will/NNP
#   the/DT
#   coverage/NN
#   extend/NN
#   to/TO
#   (PERSON Jason/NNP)
#   ?/.
#   No/DT
#   ,/,
#   he/PRP
#   's/VBZ
#   a/DT
#   freelancer/NN
#   ./.
#   I/PRP
#   do/VBP
#   n't/RB
#   think/VB
#   it/PRP
#   's/VBZ
#   a/DT
#   problem/NN
#   ./.
#   Did/NNP
#   you/PRP
#   know/VB
#   he/PRP
#   used/VBD
#   to/TO
#   be/VB
#   a/DT
#   lawyer/NN
#   ?/.
#   -/:
#   No/DT
#   ./.
#   -/:
#   He/PRP
#   practiced/VBD
#   in/IN
#   (GPE New/NNP Jersey/NNP)
#   ./.
#   He/PRP
#   was/VBD
#   disbarred/VBN
#   for/IN
#   a/DT
#   criminal/JJ
#   conviction/NN
#   ./.
#   He/PRP
#   punched/VBD
#   a/DT
#   judge/NN
#   ./.
#   He/PRP
#   punched/VBD
#   a/DT
#   judge/NN
#   ?/.
#   -/:
#   (GPE Yep/NNP)
#   ./.
#   -/:
#   Why/WRB
#   ?/.
#   I/PRP
#   guess/VBP
#   he/PRP
#   did/VBD
#   n't/RB
#   like/VB
#   his/PRP$
#   decision/NN
#   ./.
#   And/CC
#   you/PRP
#   're/VBP
#   worried/VBN
#   about/IN
#   the/DT
#   insurance/NN
#   ?/.
#   Yeah/NNP
#   ,/,
#   if/IN
#   (PERSON Jason/NNP)
#   beats/NNS
#   up/IN
#   someone/NN
#   on/IN
#   the/DT
#   job/NN
#   .../:
#   Yeah/NNP
#   ,/,
#   well/RB
#   ,/,
#   due/JJ
#   diligence/NN
#   ./.
#   We/PRP
#   should/MD
#   find/VB
#   out/RP
#   what/WP
#   happened/VBN
#   ./.
#   (PERSON Okay/NNP)
#   ,/,
#   I/PRP
#   'm/VBP
#   gon/JJ
#   na/NN
#   call/NN
#   (GPE New/NNP Jersey/NNP)
#   ./.
#   See/NNP
#   if/IN
#   I/PRP
#   can/MD
#   talk/VB
#   to/TO
#   the/DT
#   judge/NN
#   ./.
#   What/WP
#   's/VBZ
#   up/RP
#   ,/,
#   (PERSON Eli/NNP)
#   ?/.
#   What/WP
#   's/VBZ
#   the/DT
#   best/JJS
#   thing/NN
#   about/IN
#   (PERSON Peter/NNP)
#   ?/.
#   Excuse/NNP
#   me/PRP
#   ?/.
#   I/PRP
#   need/VBP
#   a/DT
#   quote/NN
#   from/IN
#   you/PRP
#   for/IN
#   (PERSON Peter/NNP)
#   's/POS
#   bio/NN
#   ./.
#   Do/NNP
#   you/PRP
#   need/VBP
#   it/PRP
#   to/TO
#   be/VB
#   true/JJ
#   ?/.
#   True/NNP
#   adjacent/NN
#   ./.
#   (PERSON Peter/NNP)
#   's/POS
#   motto/NN
#   is/VBZ
#   ``/``
#   Service/NNP
#   above/IN
#   self/PRP
#   ./.
#   My/NNP
#   family/NN
#   has/VBZ
#   benefitted/VBN
#   from/IN
#   it/PRP
#   ,/,
#   now/RB
#   (GPE America/NNP)
#   can/MD
#   ./.
#   ''/''
#   (GPE Eli/NNP)
#   ,/,
#   that/IN
#   's/POS
#   .../:
#   I/PRP
#   know/VBP
#   ,/,
#   it/PRP
#   's/VBZ
#   nauseating/VBG
#   ./.
#   Help/NNP
#   me/PRP
#   out/RP
#   ./.
#   (PERSON Eli/NNP)
#   ?/.
#   Over/NNP
#   here/RB
#   ./.
#   Just/RB
#   a/DT
#   second/JJ
#   ,/,
#   (PERSON Alicia/NNP)
#   ./.
#   I/PRP
#   thought/VBD
#   this/DT
#   was/VBD
#   a/DT
#   staff/NN
#   meeting/NN
#   ./.
#   It/PRP
#   is/VBZ
#   ./.
#   (PERSON Turn/NNP)
#   off/IN
#   your/PRP$
#   cell/NN
#   phone/NN
#   and/CC
#   I/PRP
#   'll/MD
#   turn/VB
#   off/RP
#   mine/JJ
#   ./.
#   -/:
#   What/WP
#   is/VBZ
#   it/PRP
#   ?/.
#   -/:
#   An/DT
#   (PERSON Alabama/NNP Slammer/NNP)
#   ./.
#   Yeah/NNP
#   ./.
#   I/PRP
#   like/VBP
#   them/PRP
#   strong/JJ
#   ./.
#   Confusion/NNP
#   to/TO
#   our/PRP$
#   enemies/NNS
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   are/VBP
#   we/PRP
#   discussing/VBG
#   ,/,
#   (GPE Ruth/NNP)
#   ?/.
#   What/WP
#   makes/VBZ
#   (PERSON Eli/NNP Gold/NNP)
#   tick/NN
#   ?/.
#   Uh/NNP
#   ,/,
#   I/PRP
#   know/VBP
#   how/WRB
#   this/DT
#   works/VBZ
#   ,/,
#   (GPE Ruth/NNP)
#   ./.
#   Unless/NNP
#   you/PRP
#   're/VBP
#   trying/VBG
#   to/TO
#   seduce/VB
#   me/PRP
#   ,/,
#   which/WDT
#   I/PRP
#   very/RB
#   much/RB
#   doubt/NN
#   ,/,
#   you/PRP
#   get/VBP
#   me/PRP
#   drunk/VBP
#   ,/,
#   you/PRP
#   pretend/VBP
#   to/TO
#   be/VB
#   drunk/NN
#   and/CC
#   you/PRP
#   find/VBP
#   out/RP
#   more/JJR
#   about/IN
#   me/PRP
#   than/IN
#   I/PRP
#   find/VBP
#   out/RP
#   about/IN
#   you/PRP
#   ./.
#   Oh/NNP
#   ,/,
#   (GPE Eli/NNP)
#   ,/,
#   you/PRP
#   're/VBP
#   too/RB
#   suspicious/JJ
#   ./.
#   You/PRP
#   're/VBP
#   a/DT
#   new/JJ
#   tree/NN
#   in/IN
#   my/PRP$
#   forest/NN
#   ./.
#   I/PRP
#   want/VBP
#   to/TO
#   know/VB
#   more/JJR
#   about/IN
#   that/DT
#   tree/NN
#   ,/,
#   that/IN
#   's/POS
#   all/DT
#   ./.
#   (PERSON Because/NNP)
#   unless/IN
#   I/PRP
#   chop/VBP
#   it/PRP
#   down/IN
#   ,/,
#   that/IN
#   tree/NN
#   's/POS
#   now/RB
#   part/NN
#   of/IN
#   my/PRP$
#   life/NN
#   ./.
#   -/:
#   So/RB
#   .../:
#   -/:
#   My/NNP
#   grandfather/NN
#   ,/,
#   (PERSON Samuel/NNP Gold/NNP)
#   ,/,
#   was/VBD
#   a/DT
#   teamster/NN
#   organizer/NN
#   in/IN
#   (GPE Brooklyn/NNP)
#   ./.
#   Everything/NNP
#   I/PRP
#   learned/VBD
#   ,/,
#   I/PRP
#   learned/VBD
#   from/IN
#   him/PRP
#   ./.
#   I/PRP
#   remember/VBP
#   going/VBG
#   to/TO
#   visit/VB
#   him/PRP
#   in/IN
#   his/PRP$
#   office/NN
#   when/WRB
#   I/PRP
#   was/VBD
#   little/JJ
#   ./.
#   All/DT
#   the/DT
#   people/NNS
#   coming/VBG
#   to/TO
#   kiss/NNS
#   his/PRP$
#   ring/NN
#   ./.
#   Looking/NNP
#   for/IN
#   advice/NN
#   ,/,
#   for/IN
#   help/NN
#   ./.
#   And/CC
#   he/PRP
#   told/VBD
#   me/PRP
#   that/IN
#   the/DT
#   most/RBS
#   powerful/JJ
#   men/NNS
#   are/VBP
#   the/DT
#   ones/NNS
#   that/WDT
#   no/DT
#   one/NN
#   knows/VBZ
#   exist/NN
#   ./.
#   Is/VBZ
#   something/NN
#   funny/NN
#   ?/.
#   -/:
#   (GPE Oh/NNP)
#   ,/,
#   yeah/NN
#   ./.
#   -/:
#   What/WP
#   ?/.
#   None/NNP
#   of/IN
#   that/DT
#   was/VBD
#   true/JJ
#   ./.
#   Your/NNP
#   grandfather/NN
#   was/VBD
#   (PERSON Ira/NNP Goldstein/NNP)
#   ,/,
#   owner/NN
#   of/IN
#   a/DT
#   schmatta/NN
#   business/NN
#   in/IN
#   (GPE Queens/NNP)
#   ./.
#   He/PRP
#   died/VBD
#   a/DT
#   pauper/NN
#   after/IN
#   his/PRP$
#   brother-in-law/NN
#   cheated/VBD
#   him/PRP
#   out/IN
#   of/IN
#   a/DT
#   uniform/NN
#   consignment/NN
#   with/IN
#   the/DT
#   (ORGANIZATION NYPD/NNP)
#   ./.
#   And/CC
#   that/IN
#   quote/NN
#   ?/.
#   You/PRP
#   changed/VBD
#   it/PRP
#   ./.
#   It/PRP
#   's/VBZ
#   from/IN
#   The/DT
#   (ORGANIZATION Usual/NNP Suspects/NNP)
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   do/VBP
#   you/PRP
#   want/VB
#   ,/,
#   (GPE Ruth/NNP)
#   ?/.
#   Why/NNP
#   are/VBP
#   you/PRP
#   pretending/VBG
#   to/TO
#   care/VB
#   about/IN
#   me/PRP
#   ?/.
#   We/PRP
#   got/VBD
#   new/JJ
#   internals/NNS
#   from/IN
#   this/DT
#   afternoon/NN
#   ./.
#   (PERSON Peter/NNP)
#   made/VBD
#   another/DT
#   four/CD
#   point/NN
#   bump/NN
#   ./.
#   That/DT
#   's/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   fluke/NN
#   ,/,
#   that/IN
#   's/POS
#   a/DT
#   trend/NN
#   ./.
#   We/PRP
#   broke/VBD
#   through/IN
#   ./.
#   We/PRP
#   have/VBP
#   a/DT
#   shot/NN
#   ./.
#   And/CC
#   not/RB
#   just/RB
#   at/IN
#   the/DT
#   vice/NN
#   presidency/NN
#   ./.
#   We/PRP
#   could/MD
#   win/VB
#   ./.
#   Things/NNS
#   turn/VB
#   sour/PRP$
#   for/IN
#   (PERSON Hillary/NNP)
#   .../:
#   the/DT
#   e-mails/NNS
#   ,/,
#   the/DT
#   next/JJ
#   thing/NN
#   they/PRP
#   throw/VBP
#   at/IN
#   her/PRP$
#   .../:
#   we/PRP
#   win/VBP
#   ./.
#   But/CC
#   we/PRP
#   need/VBP
#   to/TO
#   be/VB
#   rowing/VBG
#   in/IN
#   the/DT
#   same/JJ
#   direction/NN
#   ./.
#   This/DT
#   goes/VBZ
#   the/DT
#   way/NN
#   we/PRP
#   all/DT
#   want/VBP
#   ,/,
#   they/PRP
#   'll/MD
#   be/VB
#   enough/RB
#   to/TO
#   carve/VB
#   up/RP
#   for/IN
#   both/DT
#   of/IN
#   us/PRP
#   ./.
#   -/:
#   You/PRP
#   see/VBP
#   that/IN
#   ,/,
#   right/RB
#   ?/.
#   -/:
#   I/PRP
#   do/VBP
#   ./.
#   So/RB
#   the/DT
#   strategy/NN
#   's/POS
#   changed/VBN
#   ./.
#   We/PRP
#   're/VBP
#   not/RB
#   being/VBG
#   kind/NN
#   and/CC
#   deferential/JJ
#   to/TO
#   the/DT
#   frontrunner/NN
#   ./.
#   We/PRP
#   're/VBP
#   acting/VBG
#   like/IN
#   the/DT
#   frontrunner/NN
#   ./.
#   We/PRP
#   're/VBP
#   not/RB
#   aiming/VBG
#   for/IN
#   the/DT
#   vice/NN
#   presidency/NN
#   ./.
#   We/PRP
#   're/VBP
#   aiming/VBG
#   for/IN
#   the/DT
#   presidency/NN
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   do/VBP
#   you/PRP
#   need/VBP
#   from/IN
#   me/PRP
#   ?/.
#   We/PRP
#   're/VBP
#   moving/VBG
#   up/RP
#   the/DT
#   announcement/NN
#   to/TO
#   Thursday/NNP
#   ./.
#   We/PRP
#   want/VBP
#   to/TO
#   take/VB
#   advantage/NN
#   of/IN
#   the/DT
#   momentum/NN
#   ./.
#   You/PRP
#   need/VBP
#   (PERSON Alicia/NNP)
#   ?/.
#   Yes/NNP
#   ,/,
#   much/RB
#   more/RBR
#   than/IN
#   we/PRP
#   originally/RB
#   agreed/VBD
#   ./.
#   Voters/NNS
#   need/VBP
#   to/TO
#   see/VB
#   these/DT
#   two/CD
#   together/RP
#   ./.
#   (PERSON Young/NNP)
#   ,/,
#   vibrant/JJ
#   ,/,
#   looking/VBG
#   toward/IN
#   the/DT
#   future/NN
#   ./.
#   (PERSON Jackie/NNP O/NNP)
#   to/TO
#   his/PRP$
#   (ORGANIZATION JFK/NNP)
#   ./.
#   We/PRP
#   need/VBP
#   to/TO
#   work/VB
#   together/RP
#   ,/,
#   (GPE Eli/NNP)
#   ./.
#   You/PRP
#   need/VBP
#   to/TO
#   trust/VB
#   me/PRP
#   ./.
#   And/CC
#   I/PRP
#   need/VBP
#   to/TO
#   trust/VB
#   you/PRP
#   ./.
#   Who/WP
#   's/VBZ
#   that/IN
#   ?/.
#   I/PRP
#   do/VBP
#   n't/RB
#   know/VB
#   ./.
#   (PERSON Silicon/NNP Valley/NNP)
#   lawyer/NN
#   ?/.
#   -/:
#   (GPE Hello/NNP)
#   ./.
#   Alice/NNP
#   Florrick/NNP
#   ,/,
#   yes/VBZ
#   ?/.
#   -/:
#   Yes/NNP
#   ./.
#   (PERSON Andrea/NNP Stevens/NNP)
#   ./.
#   It/PRP
#   's/VBZ
#   so/RB
#   nice/JJ
#   to/TO
#   meet/VB
#   you/PRP
#   ./.
#   I/PRP
#   was/VBD
#   told/JJ
#   you/PRP
#   were/VBD
#   the/DT
#   opposing/NN
#   counsel/NN
#   ./.
#   It/PRP
#   just/RB
#   makes/VBZ
#   it/PRP
#   so/RB
#   much/RB
#   more/RBR
#   exciting/VBG
#   when/WRB
#   you/PRP
#   respect/VBP
#   the/DT
#   opposition/NN
#   ,/,
#   do/VBP
#   n't/RB
#   you/PRP
#   think/VBP
#   ?/.
#   -/:
#   It/PRP
#   does/VBZ
#   ./.
#   -/:
#   (GPE Hello/NNP)
#   ./.
#   Hi/NNP
#   ./.
#   (PERSON Lucca/NNP Quinn/NNP)
#   ./.
#   Hi/NNP
#   ./.
#   I/PRP
#   love/VBP
#   your/PRP$
#   hair/NN
#   ./.
#   How/WRB
#   many/JJ
#   years/NNS
#   are/VBP
#   you/PRP
#   out/RP
#   of/IN
#   law/NN
#   school/NN
#   ,/,
#   (PERSON Lucca/NNP)
#   ?/.
#   A/DT
#   few/JJ
#   ./.
#   Well/NNP
#   ,/,
#   that/IN
#   's/POS
#   better/JJR
#   than/IN
#   less/JJR
#   than/IN
#   a/DT
#   few/JJ
#   ./.
#   All/DT
#   rise/NN
#   ./.
#   -/:
#   (GPE Oh/NNP)
#   ,/,
#   here/RB
#   we/PRP
#   go/VBP
#   ./.
#   -/:
#   (GPE Court/NNP)
#   is/VBZ
#   now/RB
#   in/IN
#   session/NN
#   ./.
#   (PERSON Lucca/NNP)
#   ,/,
#   if/IN
#   you/PRP
#   ever/RB
#   want/VBP
#   any/DT
#   advice/NN
#   ./.
#   (PERSON Good/NNP)
#   afternoon/NN
#   ./.
#   I/PRP
#   've/VBP
#   read/JJ
#   your/PRP$
#   preliminary/JJ
#   motions/NNS
#   ./.
#   I/PRP
#   would/MD
#   like/VB
#   to/TO
#   take/VB
#   up/RP
#   the/DT
#   ,/,
#   uh/NN
#   ,/,
#   jurisdictional/JJ
#   question/NN
#   ./.
#   Your/NNP
#   Honor/NNP
#   ,/,
#   the/DT
#   plaintiff/NN
#   lives/VBZ
#   in/IN
#   (GPE Chicago/NNP)
#   .../:
#   Whoa/NNP
#   ,/,
#   whoa/NN
#   ,/,
#   whoa/NN
#   ,/,
#   whoa/NN
#   !/.
#   Your/NNP
#   Honor/NNP
#   ,/,
#   I/PRP
#   was/VBD
#   warned/VBN
#   about/IN
#   (GPE Chicago/NNP)
#   courtrooms/NNS
#   ,/,
#   but/CC
#   I/PRP
#   did/VBD
#   n't/RB
#   think/VB
#   it/PRP
#   was/VBD
#   gon/JJ
#   na/NN
#   be/VB
#   about/IN
#   who/WP
#   shouted/VBN
#   the/DT
#   loudest/JJS
#   ./.
#   It/PRP
#   is/VBZ
#   n't/RB
#   ,/,
#   (GPE Counselor/NNP)
#   ./.
#   What/WP
#   do/VBP
#   you/PRP
#   have/VB
#   ?/.
#   Thank/NNP
#   you/PRP
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ./.
#   This/DT
#   is/VBZ
#   rank/NN
#   forum/NN
#   shopping/VBG
#   ./.
#   Mrs./NNP
#   Florrick/NNP
#   knows/VBZ
#   this/DT
#   case/NN
#   belongs/VBZ
#   in/IN
#   (GPE California/NNP)
#   ./.
#   Running/NNP
#   (PERSON Milk/NNP)
#   has/VBZ
#   no/DT
#   (GPE Chicago/NNP)
#   offices/NNS
#   ./.
#   And/CC
#   the/DT
#   lie/NN
#   detector/NN
#   test/NN
#   in/IN
#   question/NN
#   took/VBD
#   place/NN
#   in/IN
#   (GPE California/NNP)
#   ./.
#   (PERSON Kristen/NNP Balko/NNP)
#   lives/VBZ
#   in/IN
#   (GPE Chicago/NNP)
#   ./.
#   And/CC
#   thanks/NNS
#   to/TO
#   the/DT
#   cloud/NN
#   tax/NN
#   passed/VBD
#   by/IN
#   the/DT
#   (ORGANIZATION Chicago/NNP City/NNP Council/NNP)
#   ,/,
#   (PERSON Running/NNP Milk/NNP)
#   's/POS
#   offices/NNS
#   are/VBP
#   both/DT
#   in/IN
#   (GPE California/NNP)
#   and/CC
#   (GPE Illinois/NNP)
#   ./.
#   Yes/NNP
#   ,/,
#   but/CC
#   respectfully/RB
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ,/,
#   they/PRP
#   are/VBP
#   not/RB
#   physically/RB
#   in/IN
#   (GPE Illinois/NNP)
#   ./.
#   But/CC
#   as/IN
#   (ORGANIZATION Running/NNP Milk/NNP)
#   and/CC
#   its/PRP$
#   ilk/NN
#   have/VBP
#   constantly/RB
#   reminded/VBN
#   us/PRP
#   :/:
#   ``/``
#   (PERSON Brick/NNP)
#   and/CC
#   mortar/NN
#   are/VBP
#   things/NNS
#   of/IN
#   the/DT
#   past/JJ
#   ./.
#   The/DT
#   cloud/NN
#   is/VBZ
#   the/DT
#   future/NN
#   ./.
#   ''/''
#   Your/NNP
#   Honor/NNP
#   ,/,
#   so/RB
#   many/JJ
#   of/IN
#   our/PRP$
#   witnesses/NNS
#   will/MD
#   have/VB
#   to/TO
#   be/VB
#   flown/VBN
#   in/IN
#   from/IN
#   (GPE San/NNP Jose/NNP)
#   and/CC
#   that/IN
#   does/VBZ
#   n't/RB
#   .../:
#   And/CC
#   so/RB
#   many/JJ
#   of/IN
#   our/PRP$
#   witnesses/NNS
#   will/MD
#   have/VB
#   -/:
#   to/TO
#   be/VB
#   flown/VBN
#   in/IN
#   from/IN
#   (GPE Chicago/NNP)
#   .../:
#   -/:
#   Your/NNP
#   Honor/NNP
#   ,/,
#   to/TO
#   refute/VB
#   these/DT
#   .../:
#   Thank/NNP
#   you/PRP
#   ./.
#   But/CC
#   as/IN
#   Ms./NNP
#   (PERSON Stevens/NNP)
#   pointed/VBD
#   out/RP
#   ,/,
#   this/DT
#   should/MD
#   n't/RB
#   be/VB
#   about/IN
#   who/WP
#   shouts/NNS
#   the/DT
#   loudest/JJS
#   ./.
#   (PERSON Motion/NNP)
#   is/VBZ
#   denied/VBN
#   ./.
#   We/PRP
#   'll/MD
#   hear/VB
#   the/DT
#   case/NN
#   here/RB
#   ./.
#   Please/NNP
#   have/VBP
#   the/DT
#   Running/NNP
#   Milk/NNP
#   software/NN
#   spec/NN
#   sent/NN
#   to/TO
#   me/PRP
#   by/IN
#   end/NN
#   of/IN
#   day/NN
#   ,/,
#   thank/NN
#   you/PRP
#   ./.
#   Just/RB
#   the/DT
#   first/JJ
#   skirmish/NN
#   ./.
#   -/:
#   (PERSON Peter/NNP)
#   wants/VBZ
#   to/TO
#   be/VB
#   president/NN
#   ./.
#   -/:
#   (PERSON Excuse/NNP)
#   me/PRP
#   ?/.
#   (PERSON Peter/NNP)
#   thinks/VBZ
#   he/PRP
#   can/MD
#   be/VB
#   president/NN
#   ./.
#   I/PRP
#   need/VBP
#   a/DT
#   drink/NN
#   ./.
#   Do/NNP
#   you/PRP
#   want/VB
#   one/CD
#   ?/.
#   No/DT
#   ,/,
#   I/PRP
#   need/VBP
#   to/TO
#   go/VB
#   ./.
#   They/PRP
#   moved/VBD
#   the/DT
#   announcement/NN
#   up/RP
#   to/TO
#   Thursday/NNP
#   ./.
#   You/PRP
#   need/VBP
#   to/TO
#   be/VB
#   in/IN
#   (GPE Springfield/NNP)
#   ./.
#   I/PRP
#   wrote/VBD
#   you/PRP
#   a/DT
#   speech/NN
#   ;/:
#   very/RB
#   (PERSON Michelle/NNP Obama/NNP)
#   ./.
#   -/:
#   What/WP
#   time/NN
#   Thursday/NNP
#   ?/.
#   -/:
#   3:00/CD
#   p.m/RB
#   ./.
#   They/PRP
#   'll/MD
#   need/VB
#   us/PRP
#   more/JJR
#   than/IN
#   usual/JJ
#   ./.
#   They/PRP
#   keep/VBP
#   mixing/VBG
#   their/PRP$
#   metaphors/NNS
#   ./.
#   You/PRP
#   're/VBP
#   either/DT
#   (PERSON Michelle/NNP Obama/NNP)
#   or/CC
#   (PERSON Jackie/NNP O/NNP)
#   ./.
#   Do/NNP
#   you/PRP
#   ever/RB
#   wonder/JJR
#   why/WRB
#   I/PRP
#   'm/VBP
#   hearing/VBG
#   this/DT
#   from/IN
#   you/PRP
#   and/CC
#   not/RB
#   (PERSON Peter/NNP)
#   ?/.
#   What/WP
#   ?/.
#   No/DT
#   ./.
#   What/WP
#   do/VBP
#   you/PRP
#   mean/VB
#   ?/.
#   Well/NNP
#   ,/,
#   I/PRP
#   'm/VBP
#   hearing/VBG
#   that/IN
#   (PERSON Peter/NNP)
#   truly/RB
#   is/VBZ
#   running/VBG
#   for/IN
#   president/NN
#   and/CC
#   that/IN
#   I/PRP
#   might/MD
#   be/VB
#   (PERSON First/NNP Lady/NNP)
#   from/IN
#   his/PRP$
#   campaign/NN
#   manager/NN
#   ./.
#   I/PRP
#   am/VBP
#   not/RB
#   his/PRP$
#   campaign/NN
#   manager/NN
#   ./.
#   You/PRP
#   think/VBP
#   he/PRP
#   has/VBZ
#   a/DT
#   chance/NN
#   ?/.
#   I/PRP
#   do/VBP
#   n't/RB
#   know/VB
#   ./.
#   I/PRP
#   thought/VBD
#   (PERSON Trump/NNP)
#   would/MD
#   self-destruct/VB
#   ,/,
#   so/RB
#   what/WP
#   do/VBP
#   I/PRP
#   know/VB
#   ?/.
#   Primaries/NNPS
#   are/VBP
#   their/PRP$
#   own/JJ
#   insanity/NN
#   ./.
#   What/WP
#   are/VBP
#   you/PRP
#   making/VBG
#   ?/.
#   A/DT
#   margarita/NN
#   ./.
#   (PERSON Tequila/NNP)
#   ,/,
#   triple/RB
#   sec/JJ
#   ./.
#   Huh/NNP
#   ./.
#   -/:
#   You/PRP
#   judging/VBG
#   me/PRP
#   ?/.
#   -/:
#   No/DT
#   ./.
#   That/DT
#   sounded/VBD
#   like/IN
#   a/DT
#   judgmental/JJ
#   huh/NN
#   ./.
#   No/DT
#   ./.
#   You/PRP
#   get/VB
#   as/IN
#   sloppy/JJ
#   drunk/NN
#   as/IN
#   you/PRP
#   want/VBP
#   to/TO
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   do/VBP
#   they/PRP
#   want/VBP
#   me/PRP
#   to/TO
#   do/VB
#   ?/.
#   Be/VB
#   involved/VBN
#   ./.
#   Go/NNP
#   on/IN
#   Thursday/NNP
#   ./.
#   Give/NNP
#   a/DT
#   good/JJ
#   speech/NN
#   ./.
#   (PERSON Look/NNP First/NNP)
#   Lady-like/NNP
#   ./.
#   I/PRP
#   got/VBD
#   (PERSON Frank/NNP Landau/NNP)
#   to/TO
#   introduce/VB
#   you/PRP
#   ./.
#   It/PRP
#   's/VBZ
#   not/RB
#   bad/JJ
#   having/NN
#   the/DT
#   head/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Democratic/JJ)
#   committee/NN
#   say/NN
#   nice/NN
#   things/NNS
#   about/IN
#   you/PRP
#   ./.
#   What/WP
#   are/VBP
#   you/PRP
#   doing/VBG
#   ,/,
#   (PERSON Eli/NNP)
#   ?/.
#   This/DT
#   does/VBZ
#   n't/RB
#   sound/VB
#   like/IN
#   you/PRP
#   ./.
#   Sure/NNP
#   it/PRP
#   does/VBZ
#   ./.
#   This/DT
#   is/VBZ
#   what/WP
#   I/PRP
#   sound/VBP
#   like/IN
#   ./.
#   No/DT
#   ,/,
#   no/DT
#   ,/,
#   no/DT
#   ,/,
#   no/DT
#   ./.
#   You/PRP
#   're/VBP
#   scheming/VBG
#   something/NN
#   here/RB
#   ./.
#   Cheers/NNS
#   ./.
#   Hey/NNP
#   ,/,
#   I/PRP
#   've/VBP
#   got/VBN
#   some/DT
#   good/JJ
#   news/NN
#   and/CC
#   I/PRP
#   got/VBD
#   some/DT
#   bad/JJ
#   news/NN
#   .../:
#   which/WDT
#   do/VBP
#   you/PRP
#   want/VB
#   first/JJ
#   ?/.
#   -/:
#   (GPE Bad/JJ)
#   ./.
#   -/:
#   (GPE Good/NNP)
#   ./.
#   Running/NNP
#   (PERSON Milk/NNP)
#   's/POS
#   HR/NNP
#   team/NN
#   definitely/RB
#   verified/VBN
#   -/:
#   (PERSON Kristen/NNP)
#   lied/VBD
#   on/IN
#   her/PRP$
#   resume/NN
#   ./.
#   -/:
#   (GPE Damn/NNP)
#   ./.
#   -/:
#   So/RB
#   we/PRP
#   have/VBP
#   no/DT
#   case/NN
#   ./.
#   -/:
#   What/WP
#   's/VBZ
#   the/DT
#   good/JJ
#   news/NN
#   ?/.
#   I/PRP
#   do/VBP
#   n't/RB
#   think/VB
#   there/EX
#   was/VBD
#   a/DT
#   theft/NN
#   at/IN
#   (FACILITY Running/NNP Milk/NNP)
#   ./.
#   What/WP
#   do/VBP
#   you/PRP
#   mean/VB
#   ?/.
#   A/DT
#   firm/NN
#   like/IN
#   (ORGANIZATION Running/NNP Milk/NNP)
#   is/VBZ
#   required/VBN
#   to/TO
#   notify/VB
#   their/PRP$
#   customers/NNS
#   of/IN
#   any/DT
#   breach/NN
#   ;/:
#   they/PRP
#   did/VBD
#   n't/RB
#   ./.
#   (GPE California/NNP)
#   attorney/NN
#   general/NN
#   's/POS
#   got/NN
#   no/DT
#   record/NN
#   of/IN
#   any/DT
#   breach/NN
#   at/IN
#   (FACILITY Running/NNP Milk/NNP)
#   ./.
#   So/RB
#   they/PRP
#   had/VBD
#   no/DT
#   reason/NN
#   to/TO
#   polygraph/VB
#   ./.
#   Right/RB
#   ,/,
#   fruit/NN
#   of/IN
#   the/DT
#   poisonous/JJ
#   tree/NN
#   ./.
#   Why/WRB
#   'd/JJ
#   you/PRP
#   punch/VBP
#   that/IN
#   judge/NN
#   ?/.
#   I/PRP
#   was/VBD
#   angry/JJ
#   ./.
#   Why/WRB
#   were/VBD
#   you/PRP
#   angry/JJ
#   ?/.
#   Do/NNP
#   n't/RB
#   you/PRP
#   get/VB
#   angry/JJ
#   ?/.
#   I/PRP
#   do/VBP
#   ,/,
#   but/CC
#   I/PRP
#   do/VBP
#   n't/RB
#   punch/VB
#   people/NNS
#   ./.
#   Maybe/NNP
#   you/PRP
#   should/MD
#   start/VB
#   ./.
#   As/IN
#   you/PRP
#   can/MD
#   see/VB
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ,/,
#   (PERSON Running/NNP Milk/NNP)
#   never/RB
#   suffered/VBD
#   a/DT
#   security/NN
#   breach/NN
#   ,/,
#   and/CC
#   since/IN
#   that/DT
#   was/VBD
#   the/DT
#   only/JJ
#   legal/JJ
#   justification/NN
#   for/IN
#   polygraphing/NN
#   our/PRP$
#   client/NN
#   ,/,
#   -/:
#   that/IN
#   polygraph/NN
#   must/MD
#   be/VB
#   thrown/VBN
#   out/RP
#   ./.
#   -/:
#   Is/VBZ
#   this/DT
#   true/JJ
#   ?/.
#   Can/NNP
#   you/PRP
#   give/VBP
#   me/PRP
#   one/CD
#   second/JJ
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ?/.
#   As/NNP
#   you/PRP
#   requested/VBD
#   ,/,
#   uh/NN
#   ,/,
#   the/DT
#   (ORGANIZATION CEO/NNP)
#   of/IN
#   Running/NNP
#   (PERSON Milk/NNP)
#   flew/VBD
#   in/IN
#   a/DT
#   great/JJ
#   personal/JJ
#   expense/NN
#   ./.
#   I/PRP
#   'm/VBP
#   honored/VBN
#   ./.
#   Without/IN
#   admitting/VBG
#   to/TO
#   any/DT
#   wrongdoing/NN
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ,/,
#   (PERSON Running/NNP Milk/NNP)
#   generously/RB
#   agrees/VBZ
#   to/TO
#   rehire/VB
#   the/DT
#   plaintiff/NN
#   at/IN
#   her/PRP$
#   original/JJ
#   salary/NN
#   ./.
#   We/PRP
#   just/RB
#   want/VBP
#   this/DT
#   to/TO
#   be/VB
#   over/IN
#   ./.
#   -/:
#   Really/RB
#   ?/.
#   Since/IN
#   when/WRB
#   ?/.
#   -/:
#   Since/IN
#   an/DT
#   hour/NN
#   ago/IN
#   ./.
#   We/PRP
#   ask/VBP
#   that/IN
#   this/DT
#   suit/NN
#   be/VB
#   dismissed/VBN
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ./.
#   Your/PRP$
#   Honor/NNP
#   ,/,
#   if/IN
#   our/PRP$
#   client/NN
#   is/VBZ
#   rehired/VBN
#   ,/,
#   she/PRP
#   ca/MD
#   n't/RB
#   be/VB
#   subjected/VBN
#   to/TO
#   a/DT
#   new/JJ
#   polygraph/NN
#   ,/,
#   is/VBZ
#   that/IN
#   correct/JJ
#   ?/.
#   Yes/NNP
#   ,/,
#   private/JJ
#   employers/NNS
#   are/VBP
#   barred/VBN
#   from/IN
#   making/VBG
#   polygraphs/NNS
#   a/DT
#   condition/NN
#   of/IN
#   employment/NN
#   ./.
#   May/NNP
#   we/PRP
#   have/VBP
#   a/DT
#   ruling/NN
#   on/IN
#   that/DT
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ?/.
#   Um/NNP
#   ,/,
#   can/MD
#   .../:
#   I'm-I/-NONE-
#   'm/JJ
#   sorry/NN
#   ,/,
#   can/MD
#   I/PRP
#   just/RB
#   have/VBP
#   one/CD
#   more/RBR
#   second/JJ
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ?/.
#   Actually/NNP
#   ,/,
#   polygraphs/VBZ
#   may/MD
#   be/VB
#   applied/VBN
#   to/TO
#   employees/NNS
#   engaged/VBN
#   in/IN
#   counterintelligence/NN
#   or/CC
#   national/JJ
#   security/NN
#   functions/NNS
#   ,/,
#   pursuant/JJ
#   to/TO
#   a/DT
#   contract/NN
#   with/IN
#   the/DT
#   federal/JJ
#   government/NN
#   ./.
#   Your/NNP
#   Honor/NNP
#   ,/,
#   our/PRP$
#   client/NN
#   has/VBZ
#   no/DT
#   connection/NN
#   with/IN
#   national/JJ
#   security/NN
#   ./.
#   And/CC
#   again/RB
#   I/PRP
#   ask/VBP
#   for/IN
#   a/DT
#   ruling/NN
#   ./.
#   These/DT
#   contracts/NNS
#   show/VBP
#   that/IN
#   (PERSON Running/NNP Milk/NNP)
#   has/VBZ
#   ongoing/VBG
#   accounts/NNS
#   with/IN
#   the/DT
#   government/NN
#   ./.
#   This/DT
#   makes/VBZ
#   no/DT
#   sense/NN
#   ./.
#   If/IN
#   these/DT
#   contracts/NNS
#   were/VBD
#   the/DT
#   reason/NN
#   for/IN
#   these/DT
#   polygraph/NN
#   tests/NNS
#   ,/,
#   then/RB
#   why/WRB
#   create/VB
#   the/DT
#   fiction/NN
#   of/IN
#   a/DT
#   security/NN
#   breach/NN
#   ?/.
#   Are/NNP
#   we/PRP
#   really/RB
#   wondering/VBG
#   why/WRB
#   the/DT
#   (ORGANIZATION National/NNP)
#   Security/NNP
#   Agency/NNP
#   might/MD
#   have/VB
#   a/DT
#   need/NN
#   for/IN
#   secrecy/NN
#   ?/.
#   Your/NNP
#   Honor/NNP
#   ,/,
#   the/DT
#   defendant/NN
#   just/RB
#   plans/VBZ
#   to/TO
#   rehire/VB
#   our/PRP$
#   client/NN
#   so/IN
#   they/PRP
#   can/MD
#   fire/VB
#   her/PRP
#   again/RB
#   ./.
#   Yes/NNS
#   ,/,
#   but/CC
#   legally/RB
#   ./.
#   These/DT
#   contracts/NNS
#   appear/VBP
#   in/IN
#   order/NN
#   ./.
#   (PERSON Before/NNP Miss/NNP Balko/NNP)
#   starts/VBZ
#   work/NN
#   again/RB
#   ,/,
#   she/PRP
#   'll/MD
#   need/VB
#   to/TO
#   submit/VB
#   to/TO
#   a/DT
#   polygraph/NN
#   ./.
#   Your/NNP
#   Honor/NNP
#   ./.
#   I/PRP
#   do/VBP
#   n't/RB
#   have/VB
#   time/NN
#   for/IN
#   this/DT
#   ,/,
#   (GPE Eli/NNP)
#   ./.
#   Even/RB
#   for/IN
#   a/DT
#   friend/NN
#   ?/.
#   If/IN
#   you/PRP
#   're/VBP
#   wearing/VBG
#   a/DT
#   wire/NN
#   ,/,
#   you/PRP
#   have/VBP
#   to/TO
#   tell/VB
#   me/PRP
#   ,/,
#   or/CC
#   it/PRP
#   'll/MD
#   be/VB
#   thrown/VBN
#   out/RP
#   in/IN
#   court/NN
#   ./.
#   I/PRP
#   am/VBP
#   not/RB
#   wearing/VBG
#   a/DT
#   wire/NN
#   ./.
#   I/PRP
#   need/VBP
#   your/PRP$
#   help/NN
#   ./.
#   I/PRP
#   would/MD
#   never/RB
#   have/VB
#   taken/VBN
#   that/IN
#   bribe/NN
#   ./.
#   I/PRP
#   did/VBD
#   n't/RB
#   need/VBN
#   you/PRP
#   to/TO
#   warn/VB
#   me/PRP
#   ./.
#   But/CC
#   I/PRP
#   did/VBD
#   warn/VB
#   you/PRP
#   ./.
#   What/WP
#   ?/.
#   What/WP
#   do/VBP
#   you/PRP
#   need/VBP
#   ?/.
#   Information/NNP
#   on/IN
#   (PERSON Frank/NNP Landau/NNP)
#   and/CC
#   his/PRP$
#   manipulation/NN
#   of/IN
#   voting/NN
#   machines/NNS
#   in/IN
#   the/DT
#   last/JJ
#   election/NN
#   ./.
#   -/:
#   No/DT
#   ,/,
#   I/PRP
#   wo/MD
#   n't/RB
#   betray/VB
#   him/PRP
#   ./.
#   -/:
#   He/PRP
#   wo/MD
#   n't/RB
#   know/VB
#   it/PRP
#   's/VBZ
#   you/PRP
#   ./.
#   I/PRP
#   just/RB
#   need/VBP
#   the/DT
#   proof/NN
#   from/IN
#   you/PRP
#   ,/,
#   and/CC
#   I/PRP
#   'll/MD
#   do/VB
#   the/DT
#   rest/NN
#   ./.
#   What/WP
#   are/VBP
#   you/PRP
#   up/IN
#   to/TO
#   ?/.
#   (/:
#   .../:
#   )/:)

# %%
from nltk.corpus import treebank
t = treebank.parsed_sents('wsj_0001.mrg')[0]
t.draw()

# %%
sents = nltk.sent_tokenize(text)
print(sents)
# Out:
# [u'Do you want me to sit here?', u'No, here is fine.', u"- You're Kristen Balko?", u'- Yes.', u"And you're VP of Information Security at Running Milk?", u"That's right.", u'Um, is this part of the test?', u'No, just the pre-test.', u'Think of this as a practice run.', u"We gather some background information, then go over the questions you'll be asked.", u"You're gonna tell me the questions on the test - before the test?", u"- That's right.", u"Isn't that cheating?", u"Uh, no, it isn't like the movies, Ms. Balko.", u'There are no "gotcha moments".', u"You'll know every question beforehand.", u'Okay, got it.', u'Fire away.', u'Have you ever shared confidential materials with individuals not employed with Running Milk?', u'No, never.', u'Am I supposed to answer?', u'Anything you want.', u'Have you ever stolen anything from your workplace?', u'Never.', u'Have you ever lied to the company?', u'No.', u'I lied.', u'You did steal materials from the workplace?', u'No, I lied by saying I never lied to the company.', u'Could you be more specific?', u'When I applied, in my r\xe9sum\xe9 I told them that I worked as a VP of Information Technology at a previous company.', u'But there was no VP of Information Technology.', u"- Oh, that's it?", u'- Yes, what do you mean?', u'They fired you because you said you were a VP on your r\xe9sum\xe9?', u'No, they fired me because I lied in the lie detector test.', u"But that wasn't the point of the lie detector test, right?", u'They were trying to find someone who stole - confidential materials.', u'- Right.', u"And you didn't do that.", u'Did you try to explain that to your boss?', u'Yes, but they said I lied to the company, so they could fire me.', u"That's why I'm suing.", u"Silicon Valley's a very provincial town.", u"I can't get a job anywhere.", u'Well, The Polygraph Protection Act keeps an employer from forcing you to take a lie detector test, but there are exceptions.', u'Theft.', u'Uh, Kristen, this is our investigator Jason.', u'Hi.', u"But I didn't steal anything.", u'Yes, but it was the reason for the polygraph.', u'They caught you in another lie, but...', u'They need corroborating evidence.', u'Right.', u"And they couldn't have fired her unless they already had some evidence that she lied on her r\xe9sum\xe9.", u'Did they, Kristen?', u'Have evidence I lied?', u"No, I don't think so.", u'The whole point of the polygraph was about this theft.', u"Okay, um, why don't you give us the day to think about it?", u"Actually, I don't have a day.", u"Mr. Canning told me you'd be able to move faster than he could.", u'- Louis Canning?', u'- Yes.', u"He already filed the suit, but he got busy with another case, and he thought you'd be good to take it over.", u"I'm sure he did.", u'All right, I will see if they have any corroborating evidence.', u"Good, a polygraph can't be the sole basis for firing.", u'So what... cap my work off at five hours?', u'- Yeah.', u'- Okay.', u'So, what did you find out about insurance?', u'Oh, yeah.', u'Malpractice insurance is a fortune, but we could bundle it.', u"I can get a rider to your homeowner's policy, and just split the increase in your premium?", u'Will the coverage extend to Jason?', u"No, he's a freelancer.", u"I don't think it's a problem.", u'Did you know he used to be a lawyer?', u'- No.', u'- He practiced in New Jersey.', u'He was disbarred for a criminal conviction.', u'He punched a judge.', u'He punched a judge?', u'- Yep.', u'- Why?', u"I guess he didn't like his decision.", u"And you're worried about the insurance?", u'Yeah, if Jason beats up someone on the job... \nYeah, well, due diligence.', u'We should find out what happened.', u"Okay, I'm gonna call New Jersey.", u'See if I can talk to the judge.', u"What's up, Eli?", u"What's the best thing about Peter?", u'Excuse me?', u"I need a quote from you for Peter's bio.", u'Do you need it to be true?', u'True adjacent.', u'Peter\'s motto is "Service above self.', u'My family has benefitted from it, now Am ...

# %%
tokens = nltk.word_tokenize(text)
print tokens
# Out:
# [u'Do', u'you', u'want', u'me', u'to', u'sit', u'here', u'?', u'No', u',', u'here', u'is', u'fine', u'.', u'-', u'You', u"'re", u'Kristen', u'Balko', u'?', u'-', u'Yes', u'.', u'And', u'you', u"'re", u'VP', u'of', u'Information', u'Security', u'at', u'Running', u'Milk', u'?', u'That', u"'s", u'right', u'.', u'Um', u',', u'is', u'this', u'part', u'of', u'the', u'test', u'?', u'No', u',', u'just', u'the', u'pre-test', u'.', u'Think', u'of', u'this', u'as', u'a', u'practice', u'run', u'.', u'We', u'gather', u'some', u'background', u'information', u',', u'then', u'go', u'over', u'the', u'questions', u'you', u"'ll", u'be', u'asked', u'.', u'You', u"'re", u'gon', u'na', u'tell', u'me', u'the', u'questions', u'on', u'the', u'test', u'-', u'before', u'the', u'test', u'?', u'-', u'That', u"'s", u'right', u'.', u'Is', u"n't", u'that', u'cheating', u'?', u'Uh', u',', u'no', u',', u'it', u'is', u"n't", u'like', u'the', u'movies', u',', u'Ms.', u'Balko', u'.', u'There', u'are', u'no', u'``', u'gotcha', u'moments', u"''", u'.', u'You', u"'ll", u'know', u'every', u'question', u'beforehand', u'.', u'Okay', u',', u'got', u'it', u'.', u'Fire', u'away', u'.', u'Have', u'you', u'ever', u'shared', u'confidential', u'materials', u'with', u'individuals', u'not', u'employed', u'with', u'Running', u'Milk', u'?', u'No', u',', u'never', u'.', u'Am', u'I', u'supposed', u'to', u'answer', u'?', u'Anything', u'you', u'want', u'.', u'Have', u'you', u'ever', u'stolen', u'anything', u'from', u'your', u'workplace', u'?', u'Never', u'.', u'Have', u'you', u'ever', u'lied', u'to', u'the', u'company', u'?', u'No', u'.', u'I', u'lied', u'.', u'You', u'did', u'steal', u'materials', u'from', u'the', u'workplace', u'?', u'No', u',', u'I', u'lied', u'by', u'saying', u'I', u'never', u'lied', u'to', u'the', u'company', u'.', u'Could', u'you', u'be', u'more', u'specific', u'?', u'When', u'I', u'applied', u',', u'in', u'my', u'r\xe9sum\xe9', u'I', u'told', u'them', u'that', u'I', u'worked', u'as', u'a', u'VP', u'of', u'Information', u'Technology', u'at', u'a', u'previous', u'company', u'.', u'But', u'there', u'was', u'no', u'VP', u'of', u'Information', u'Technology', u'.', u'-', u'Oh', u',', u'that', u"'s", u'it', u'?', u'-', u'Yes', u',', u'what', u'do', u'you', u'mean', u'?', u'They', u'fired', u'you', u'because', u'you', u'said', u'you', u'were', u'a', u'VP', u'on', u'your', u'r\xe9sum\xe9', u'?', u'No', u',', u'they', u'fired', u'me', u'because', u'I', u'lied', u'in', u'the', u'lie', u'detector', u'test', u'.', u'But', u'that', u'was', u"n't", u'the', u'point', u'of', u'the', u'lie', u'detector', u'test', u',', u'right', u'?', u'They', u'were', u'trying', u'to', u'find', u'someone', u'who', u'stole', u'-', u'confidential', u'materials', u'.', u'-', u'Right', u'.', u'And', u'you', u'did', u"n't", u'do', u'that', u'.', u'Did', u'you', u'try', u'to', u'explain', u'that', u'to', u'your', u'boss', u'?', u'Yes', u',', u'but', u'they', u'said', u'I', u'lied', u'to', u'the', u'company', u',', u'so', u'they', u'could', u'fire', u'me', u'.', u'That', u"'s", u'why', u'I', u"'m", u'suing', u'.', u'Silicon', u'Valley', u"'s", u'a', u'very', u'provincial', u'town', u'.', u'I', u'ca', u"n't", u'get', u'a', u'job', u'anywhere', u'.', u'Well', u',', u'The', u'Polygraph', u'Protection', u'Act', u'keeps', u'an', u'employer', u'from', u'forcing', u'you', u'to', u'take', u'a', u'lie', u'detector', u'test', u',', u'but', u'there', u'are', u'exceptions', u'.', u'Theft', u'.', u'Uh', u',', u'Kristen', u',', u'this', u'is', u'our', u'investigator', u'Jason', u'.', u'Hi', u'.', u'But', u'I', u'did', u"n't", u'steal', u'anything', u'.', u'Yes', u',', u'but', u'it', u'was', u'the', u'reason', u'for', u'the', u'polygraph', u'.', u'They', u'caught', u'you', u'in', u'another', u'lie', u',', u'but', u'...', u'They', u'need', u'corroborating', u'evidence', u'.', u'Right', u'.', u'And', u'they', u'could', u"n't", u'have', u'fired', u'her', u'unless', u'they', u'already', u'had', u'some', u'evidence', u' ...

# %%
tagged = nltk.pos_tag(tokens)
print(nltk.ne_chunk(tagged))
# Out:
# (S
#   Do/NNP
#   you/PRP
#   want/VB
#   me/PRP
#   to/TO
#   sit/VB
#   here/RB
#   ?/.
#   No/DT
#   ,/,
#   here/RB
#   is/VBZ
#   fine/NN
#   ./.
#   -/:
#   You/PRP
#   're/VBP
#   (PERSON Kristen/NNP Balko/NNP)
#   ?/.
#   -/:
#   Yes/NNP
#   ./.
#   And/CC
#   you/PRP
#   're/VBP
#   VP/NNP
#   of/IN
#   (ORGANIZATION Information/NNP)
#   Security/NNP
#   at/IN
#   (FACILITY Running/NNP Milk/NNP)
#   ?/.
#   That/DT
#   's/VBZ
#   right/RB
#   ./.
#   Um/NNP
#   ,/,
#   is/VBZ
#   this/DT
#   part/NN
#   of/IN
#   the/DT
#   test/NN
#   ?/.
#   No/DT
#   ,/,
#   just/RB
#   the/DT
#   pre-test/JJ
#   ./.
#   Think/NNP
#   of/IN
#   this/DT
#   as/IN
#   a/DT
#   practice/NN
#   run/VBN
#   ./.
#   We/PRP
#   gather/RB
#   some/DT
#   background/NN
#   information/NN
#   ,/,
#   then/RB
#   go/VB
#   over/IN
#   the/DT
#   questions/NNS
#   you/PRP
#   'll/MD
#   be/VB
#   asked/VBN
#   ./.
#   You/PRP
#   're/VBP
#   gon/JJ
#   na/NN
#   tell/NN
#   me/PRP
#   the/DT
#   questions/NNS
#   on/IN
#   the/DT
#   test/NN
#   -/:
#   before/IN
#   the/DT
#   test/NN
#   ?/.
#   -/:
#   That/DT
#   's/VBZ
#   right/RB
#   ./.
#   Is/VBZ
#   n't/RB
#   that/IN
#   cheating/NN
#   ?/.
#   Uh/NNP
#   ,/,
#   no/DT
#   ,/,
#   it/PRP
#   is/VBZ
#   n't/RB
#   like/IN
#   the/DT
#   movies/NNS
#   ,/,
#   Ms./NNP
#   Balko/NNP
#   ./.
#   There/EX
#   are/VBP
#   no/DT
#   ``/``
#   gotcha/NN
#   moments/NNS
#   ''/''
#   ./.
#   You/PRP
#   'll/MD
#   know/VB
#   every/DT
#   question/NN
#   beforehand/NN
#   ./.
#   (PERSON Okay/NNP)
#   ,/,
#   got/VBD
#   it/PRP
#   ./.
#   (PERSON Fire/NNP)
#   away/RB
#   ./.
#   Have/NNP
#   you/PRP
#   ever/RB
#   shared/VBN
#   confidential/JJ
#   materials/NNS
#   with/IN
#   individuals/NNS
#   not/RB
#   employed/VBN
#   with/IN
#   (PERSON Running/NNP Milk/NNP)
#   ?/.
#   No/DT
#   ,/,
#   never/RB
#   ./.
#   Am/NNP
#   I/PRP
#   supposed/VBD
#   to/TO
#   answer/VB
#   ?/.
#   Anything/NNP
#   you/PRP
#   want/VBP
#   ./.
#   Have/NNP
#   you/PRP
#   ever/RB
#   stolen/VBN
#   anything/NN
#   from/IN
#   your/PRP$
#   workplace/NN
#   ?/.
#   Never/NNP
#   ./.
#   Have/NNP
#   you/PRP
#   ever/RB
#   lied/VBN
#   to/TO
#   the/DT
#   company/NN
#   ?/.
#   No/NNP
#   ./.
#   I/PRP
#   lied/VBD
#   ./.
#   You/PRP
#   did/VBD
#   steal/JJ
#   materials/NNS
#   from/IN
#   the/DT
#   workplace/NN
#   ?/.
#   No/DT
#   ,/,
#   I/PRP
#   lied/VBD
#   by/IN
#   saying/VBG
#   I/PRP
#   never/RB
#   lied/VBD
#   to/TO
#   the/DT
#   company/NN
#   ./.
#   Could/MD
#   you/PRP
#   be/VB
#   more/RBR
#   specific/JJ
#   ?/.
#   When/WRB
#   I/PRP
#   applied/VBD
#   ,/,
#   in/IN
#   my/PRP$
#   resume/NN
#   I/PRP
#   told/VBD
#   them/PRP
#   that/IN
#   I/PRP
#   worked/VBD
#   as/IN
#   a/DT
#   VP/NNP
#   of/IN
#   (ORGANIZATION Information/NNP Technology/NNP)
#   at/IN
#   a/DT
#   previous/JJ
#   company/NN
#   ./.
#   But/CC
#   there/EX
#   was/VBD
#   no/DT
#   VP/NNP
#   of/IN
#   (ORGANIZATION Information/NNP Technology/NNP)
#   ./.
#   -/:
#   (GPE Oh/NNP)
#   ,/,
#   that/IN
#   's/POS
#   it/PRP
#   ?/.
#   -/:
#   (GPE Yes/NNP)
#   ,/,
#   what/WP
#   do/VBP
#   you/PRP
#   mean/VB
#   ?/.
#   They/PRP
#   fired/VBD
#   you/PRP
#   because/IN
#   you/PRP
#   said/VBD
#   you/PRP
#   were/VBD
#   a/DT
#   VP/NNP
#   on/IN
#   your/PRP$
#   resume/NN
#   ?/.
#   No/DT
#   ,/,
#   they/PRP
#   fired/VBD
#   me/PRP
#   because/IN
#   I/PRP
#   lied/VBD
#   in/IN
#   the/DT
#   lie/NN
#   detector/NN
#   test/NN
#   ./.
#   But/CC
#   that/IN
#   was/VBD
#   n't/RB
#   the/DT
#   point/NN
#   of/IN
#   the/DT
#   lie/NN
#   detector/NN
#   test/NN
#   ,/,
#   right/RB
#   ?/.
#   They/PRP
#   were/VBD
#   trying/VBG
#   to/TO
#   find/VB
#   someone/NN
#   who/WP
#   stole/NN
#   -/:
#   confidential/JJ
#   materials/NNS
#   ./.
#   -/:
#   (GPE Right/NNP)
#   ./.
#   And/CC
#   you/PRP
#   did/VBD
#   n't/RB
#   do/VB
#   that/DT
#   ./.
#   Did/NNP
#   you/PRP
#   try/VBP
#   to/TO
#   explain/VB
#   that/IN
#   to/TO
#   your/PRP$
#   boss/NN
#   ?/.
#   Yes/NNP
#   ,/,
#   but/CC
#   they/PRP
#   said/VBD
#   I/PRP
#   lied/VBD
#   to/TO
#   the/DT
#   company/NN
#   ,/,
#   so/RB
#   they/PRP
#   could/MD
#   fire/VB
#   me/PRP
#   ./.
#   That/DT
#   's/VBZ
#   why/WRB
#   I/PRP
#   'm/VBP
#   suing/VBG
#   ./.
#   (PERSON Silicon/NNP Valley/NNP)
#   's/POS
#   a/DT
#   very/RB
#   provincial/JJ
#   town/NN
#   ./.
#   I/PRP
#   ca/MD
#   n't/RB
#   get/VB
#   a/DT
#   job/NN
#   anywhere/RB
#   ./.
#   Well/NNP
#   ,/,
#   (ORGANIZATION The/NNP Polygraph/NNP)
#   Protection/NNP
#   Act/NNP
#   keeps/VBZ
#   an/DT
#   employer/NN
#   from/IN
#   forcing/JJ
#   you/PRP
#   to/TO
#   take/VB
#   a/DT
#   lie/NN
#   detector/NN
#   test/NN
#   ,/,
#   but/CC
#   there/EX
#   are/VBP
#   exceptions/NNS
#   ./.
#   Theft/NNP
#   ./.
#   Uh/NNP
#   ,/,
#   (PERSON Kristen/NNP)
#   ,/,
#   this/DT
#   is/VBZ
#   our/PRP$
#   investigator/NN
#   (PERSON Jason/NNP)
#   ./.
#   Hi/NNP
#   ./.
#   But/CC
#   I/PRP
#   did/VBD
#   n't/RB
#   steal/VB
#   anything/NN
#   ./.
#   Yes/NNP
#   ,/,
#   but/CC
#   it/PRP
#   was/VBD
#   the/DT
#   reason/NN
#   for/IN
#   the/DT
#   polygraph/NN
#   ./.
#   They/PRP
#   caught/VBD
#   you/PRP
#   in/IN
#   another/DT
#   lie/NN
#   ,/,
#   but/CC
#   .../:
#   They/PRP
#   need/VBP
#   corroborating/VBG
#   evidence/NN
#   ./.
#   Right/NNP
#   ./.
#   And/CC
#   they/PRP
#   could/MD
#   n't/RB
#   have/VB
#   fired/VBN
#   her/PRP
#   unless/IN
#   they/PRP
#   already/RB
#   had/VBD
#   some/DT
#   evidence/NN
#   that/IN
#   she/PRP
#   lied/VBD
#   on/IN
#   her/PRP$
#   resume/NN
#   ./.
#   Did/NNP
#   they/PRP
#   ,/,
#   (PERSON Kristen/NNP)
#   ?/.
#   Have/NNP
#   evidence/NN
#   I/PRP
#   lied/VBD
#   ?/.
#   No/DT
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   think/VB
#   so/RB
#   ./.
#   The/DT
#   whole/JJ
#   point/NN
#   of/IN
#   the/DT
#   polygraph/NN
#   was/VBD
#   about/IN
#   this/DT
#   theft/NN
#   ./.
#   (PERSON Okay/NNP)
#   ,/,
#   um/NN
#   ,/,
#   why/WRB
#   do/VBP
#   n't/RB
#   you/PRP
#   give/VB
#   us/PRP
#   the/DT
#   day/NN
#   to/TO
#   think/VB
#   about/IN
#   it/PRP
#   ?/.
#   Actually/RB
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   have/VB
#   a/DT
#   day/NN
#   ./.
#   (PERSON Mr./NNP Canning/NNP)
#   told/VBD
#   me/PRP
#   you/PRP
#   'd/MD
#   be/VB
#   able/JJ
#   to/TO
#   move/VB
#   faster/JJR
#   than/IN
#   he/PRP
#   could/MD
#   ./.
#   -/:
#   (PERSON Louis/NNP Canning/NNP)
#   ?/.
#   -/:
#   Yes/NNP
#   ./.
#   He/PRP
#   already/RB
#   filed/VBN
#   the/DT
#   suit/NN
#   ,/,
#   but/CC
#   he/PRP
#   got/VBD
#   busy/JJ
#   with/IN
#   another/DT
#   case/NN
#   ,/,
#   and/CC
#   he/PRP
#   thought/VBD
#   you/PRP
#   'd/MD
#   be/VB
#   good/JJ
#   to/TO
#   take/VB
#   it/PRP
#   over/IN
#   ./.
#   I/PRP
#   'm/VBP
#   sure/JJ
#   he/PRP
#   did/VBD
#   ./.
#   All/DT
#   right/NN
#   ,/,
#   I/PRP
#   will/MD
#   see/VB
#   if/IN
#   they/PRP
#   have/VBP
#   any/DT
#   corroborating/VBG
#   evidence/NN
#   ./.
#   (PERSON Good/NNP)
#   ,/,
#   a/DT
#   polygraph/NN
#   ca/MD
#   n't/RB
#   be/VB
#   the/DT
#   sole/JJ
#   basis/NN
#   for/IN
#   firing/NN
#   ./.
#   So/RB
#   what/WP
#   .../:
#   cap/NN
#   my/PRP$
#   work/NN
#   off/RP
#   at/IN
#   five/CD
#   hours/NNS
#   ?/.
#   -/:
#   (GPE Yeah/NNP)
#   ./.
#   -/:
#   (GPE Okay/NNP)
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   did/VBD
#   you/PRP
#   find/VBP
#   out/RP
#   about/IN
#   insurance/NN
#   ?/.
#   Oh/NNP
#   ,/,
#   yeah/NN
#   ./.
#   Malpractice/NNP
#   insurance/NN
#   is/VBZ
#   a/DT
#   fortune/NN
#   ,/,
#   but/CC
#   we/PRP
#   could/MD
#   bundle/VB
#   it/PRP
#   ./.
#   I/PRP
#   can/MD
#   get/VB
#   a/DT
#   rider/NN
#   to/TO
#   your/PRP$
#   homeowner/NN
#   's/POS
#   policy/NN
#   ,/,
#   and/CC
#   just/RB
#   split/JJ
#   the/DT
#   increase/NN
#   in/IN
#   your/PRP$
#   premium/NN
#   ?/.
#   Will/NNP
#   the/DT
#   coverage/NN
#   extend/NN
#   to/TO
#   (PERSON Jason/NNP)
#   ?/.
#   No/DT
#   ,/,
#   he/PRP
#   's/VBZ
#   a/DT
#   freelancer/NN
#   ./.
#   I/PRP
#   do/VBP
#   n't/RB
#   think/VB
#   it/PRP
#   's/VBZ
#   a/DT
#   problem/NN
#   ./.
#   Did/NNP
#   you/PRP
#   know/VB
#   he/PRP
#   used/VBD
#   to/TO
#   be/VB
#   a/DT
#   lawyer/NN
#   ?/.
#   -/:
#   No/DT
#   ./.
#   -/:
#   He/PRP
#   practiced/VBD
#   in/IN
#   (GPE New/NNP Jersey/NNP)
#   ./.
#   He/PRP
#   was/VBD
#   disbarred/VBN
#   for/IN
#   a/DT
#   criminal/JJ
#   conviction/NN
#   ./.
#   He/PRP
#   punched/VBD
#   a/DT
#   judge/NN
#   ./.
#   He/PRP
#   punched/VBD
#   a/DT
#   judge/NN
#   ?/.
#   -/:
#   (GPE Yep/NNP)
#   ./.
#   -/:
#   Why/WRB
#   ?/.
#   I/PRP
#   guess/VBP
#   he/PRP
#   did/VBD
#   n't/RB
#   like/VB
#   his/PRP$
#   decision/NN
#   ./.
#   And/CC
#   you/PRP
#   're/VBP
#   worried/VBN
#   about/IN
#   the/DT
#   insurance/NN
#   ?/.
#   Yeah/NNP
#   ,/,
#   if/IN
#   (PERSON Jason/NNP)
#   beats/NNS
#   up/IN
#   someone/NN
#   on/IN
#   the/DT
#   job/NN
#   .../:
#   Yeah/NNP
#   ,/,
#   well/RB
#   ,/,
#   due/JJ
#   diligence/NN
#   ./.
#   We/PRP
#   should/MD
#   find/VB
#   out/RP
#   what/WP
#   happened/VBN
#   ./.
#   (PERSON Okay/NNP)
#   ,/,
#   I/PRP
#   'm/VBP
#   gon/JJ
#   na/NN
#   call/NN
#   (GPE New/NNP Jersey/NNP)
#   ./.
#   See/NNP
#   if/IN
#   I/PRP
#   can/MD
#   talk/VB
#   to/TO
#   the/DT
#   judge/NN
#   ./.
#   What/WP
#   's/VBZ
#   up/RP
#   ,/,
#   (PERSON Eli/NNP)
#   ?/.
#   What/WP
#   's/VBZ
#   the/DT
#   best/JJS
#   thing/NN
#   about/IN
#   (PERSON Peter/NNP)
#   ?/.
#   Excuse/NNP
#   me/PRP
#   ?/.
#   I/PRP
#   need/VBP
#   a/DT
#   quote/NN
#   from/IN
#   you/PRP
#   for/IN
#   (PERSON Peter/NNP)
#   's/POS
#   bio/NN
#   ./.
#   Do/NNP
#   you/PRP
#   need/VBP
#   it/PRP
#   to/TO
#   be/VB
#   true/JJ
#   ?/.
#   True/NNP
#   adjacent/NN
#   ./.
#   (PERSON Peter/NNP)
#   's/POS
#   motto/NN
#   is/VBZ
#   ``/``
#   Service/NNP
#   above/IN
#   self/PRP
#   ./.
#   My/NNP
#   family/NN
#   has/VBZ
#   benefitted/VBN
#   from/IN
#   it/PRP
#   ,/,
#   now/RB
#   (GPE America/NNP)
#   can/MD
#   ./.
#   ''/''
#   (GPE Eli/NNP)
#   ,/,
#   that/IN
#   's/POS
#   .../:
#   I/PRP
#   know/VBP
#   ,/,
#   it/PRP
#   's/VBZ
#   nauseating/VBG
#   ./.
#   Help/NNP
#   me/PRP
#   out/RP
#   ./.
#   (PERSON Eli/NNP)
#   ?/.
#   Over/NNP
#   here/RB
#   ./.
#   Just/RB
#   a/DT
#   second/JJ
#   ,/,
#   (PERSON Alicia/NNP)
#   ./.
#   I/PRP
#   thought/VBD
#   this/DT
#   was/VBD
#   a/DT
#   staff/NN
#   meeting/NN
#   ./.
#   It/PRP
#   is/VBZ
#   ./.
#   (PERSON Turn/NNP)
#   off/IN
#   your/PRP$
#   cell/NN
#   phone/NN
#   and/CC
#   I/PRP
#   'll/MD
#   turn/VB
#   off/RP
#   mine/JJ
#   ./.
#   -/:
#   What/WP
#   is/VBZ
#   it/PRP
#   ?/.
#   -/:
#   An/DT
#   (PERSON Alabama/NNP Slammer/NNP)
#   ./.
#   Yeah/NNP
#   ./.
#   I/PRP
#   like/VBP
#   them/PRP
#   strong/JJ
#   ./.
#   Confusion/NNP
#   to/TO
#   our/PRP$
#   enemies/NNS
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   are/VBP
#   we/PRP
#   discussing/VBG
#   ,/,
#   (GPE Ruth/NNP)
#   ?/.
#   What/WP
#   makes/VBZ
#   (PERSON Eli/NNP Gold/NNP)
#   tick/NN
#   ?/.
#   Uh/NNP
#   ,/,
#   I/PRP
#   know/VBP
#   how/WRB
#   this/DT
#   works/VBZ
#   ,/,
#   (GPE Ruth/NNP)
#   ./.
#   Unless/NNP
#   you/PRP
#   're/VBP
#   trying/VBG
#   to/TO
#   seduce/VB
#   me/PRP
#   ,/,
#   which/WDT
#   I/PRP
#   very/RB
#   much/RB
#   doubt/NN
#   ,/,
#   you/PRP
#   get/VBP
#   me/PRP
#   drunk/VBP
#   ,/,
#   you/PRP
#   pretend/VBP
#   to/TO
#   be/VB
#   drunk/NN
#   and/CC
#   you/PRP
#   find/VBP
#   out/RP
#   more/JJR
#   about/IN
#   me/PRP
#   than/IN
#   I/PRP
#   find/VBP
#   out/RP
#   about/IN
#   you/PRP
#   ./.
#   Oh/NNP
#   ,/,
#   (GPE Eli/NNP)
#   ,/,
#   you/PRP
#   're/VBP
#   too/RB
#   suspicious/JJ
#   ./.
#   You/PRP
#   're/VBP
#   a/DT
#   new/JJ
#   tree/NN
#   in/IN
#   my/PRP$
#   forest/NN
#   ./.
#   I/PRP
#   want/VBP
#   to/TO
#   know/VB
#   more/JJR
#   about/IN
#   that/DT
#   tree/NN
#   ,/,
#   that/IN
#   's/POS
#   all/DT
#   ./.
#   (PERSON Because/NNP)
#   unless/IN
#   I/PRP
#   chop/VBP
#   it/PRP
#   down/IN
#   ,/,
#   that/IN
#   tree/NN
#   's/POS
#   now/RB
#   part/NN
#   of/IN
#   my/PRP$
#   life/NN
#   ./.
#   -/:
#   So/RB
#   .../:
#   -/:
#   My/NNP
#   grandfather/NN
#   ,/,
#   (PERSON Samuel/NNP Gold/NNP)
#   ,/,
#   was/VBD
#   a/DT
#   teamster/NN
#   organizer/NN
#   in/IN
#   (GPE Brooklyn/NNP)
#   ./.
#   Everything/NNP
#   I/PRP
#   learned/VBD
#   ,/,
#   I/PRP
#   learned/VBD
#   from/IN
#   him/PRP
#   ./.
#   I/PRP
#   remember/VBP
#   going/VBG
#   to/TO
#   visit/VB
#   him/PRP
#   in/IN
#   his/PRP$
#   office/NN
#   when/WRB
#   I/PRP
#   was/VBD
#   little/JJ
#   ./.
#   All/DT
#   the/DT
#   people/NNS
#   coming/VBG
#   to/TO
#   kiss/NNS
#   his/PRP$
#   ring/NN
#   ./.
#   Looking/NNP
#   for/IN
#   advice/NN
#   ,/,
#   for/IN
#   help/NN
#   ./.
#   And/CC
#   he/PRP
#   told/VBD
#   me/PRP
#   that/IN
#   the/DT
#   most/RBS
#   powerful/JJ
#   men/NNS
#   are/VBP
#   the/DT
#   ones/NNS
#   that/WDT
#   no/DT
#   one/NN
#   knows/VBZ
#   exist/NN
#   ./.
#   Is/VBZ
#   something/NN
#   funny/NN
#   ?/.
#   -/:
#   (GPE Oh/NNP)
#   ,/,
#   yeah/NN
#   ./.
#   -/:
#   What/WP
#   ?/.
#   None/NNP
#   of/IN
#   that/DT
#   was/VBD
#   true/JJ
#   ./.
#   Your/NNP
#   grandfather/NN
#   was/VBD
#   (PERSON Ira/NNP Goldstein/NNP)
#   ,/,
#   owner/NN
#   of/IN
#   a/DT
#   schmatta/NN
#   business/NN
#   in/IN
#   (GPE Queens/NNP)
#   ./.
#   He/PRP
#   died/VBD
#   a/DT
#   pauper/NN
#   after/IN
#   his/PRP$
#   brother-in-law/NN
#   cheated/VBD
#   him/PRP
#   out/IN
#   of/IN
#   a/DT
#   uniform/NN
#   consignment/NN
#   with/IN
#   the/DT
#   (ORGANIZATION NYPD/NNP)
#   ./.
#   And/CC
#   that/IN
#   quote/NN
#   ?/.
#   You/PRP
#   changed/VBD
#   it/PRP
#   ./.
#   It/PRP
#   's/VBZ
#   from/IN
#   The/DT
#   (ORGANIZATION Usual/NNP Suspects/NNP)
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   do/VBP
#   you/PRP
#   want/VB
#   ,/,
#   (GPE Ruth/NNP)
#   ?/.
#   Why/NNP
#   are/VBP
#   you/PRP
#   pretending/VBG
#   to/TO
#   care/VB
#   about/IN
#   me/PRP
#   ?/.
#   We/PRP
#   got/VBD
#   new/JJ
#   internals/NNS
#   from/IN
#   this/DT
#   afternoon/NN
#   ./.
#   (PERSON Peter/NNP)
#   made/VBD
#   another/DT
#   four/CD
#   point/NN
#   bump/NN
#   ./.
#   That/DT
#   's/VBZ
#   more/JJR
#   than/IN
#   a/DT
#   fluke/NN
#   ,/,
#   that/IN
#   's/POS
#   a/DT
#   trend/NN
#   ./.
#   We/PRP
#   broke/VBD
#   through/IN
#   ./.
#   We/PRP
#   have/VBP
#   a/DT
#   shot/NN
#   ./.
#   And/CC
#   not/RB
#   just/RB
#   at/IN
#   the/DT
#   vice/NN
#   presidency/NN
#   ./.
#   We/PRP
#   could/MD
#   win/VB
#   ./.
#   Things/NNS
#   turn/VB
#   sour/PRP$
#   for/IN
#   (PERSON Hillary/NNP)
#   .../:
#   the/DT
#   e-mails/NNS
#   ,/,
#   the/DT
#   next/JJ
#   thing/NN
#   they/PRP
#   throw/VBP
#   at/IN
#   her/PRP$
#   .../:
#   we/PRP
#   win/VBP
#   ./.
#   But/CC
#   we/PRP
#   need/VBP
#   to/TO
#   be/VB
#   rowing/VBG
#   in/IN
#   the/DT
#   same/JJ
#   direction/NN
#   ./.
#   This/DT
#   goes/VBZ
#   the/DT
#   way/NN
#   we/PRP
#   all/DT
#   want/VBP
#   ,/,
#   they/PRP
#   'll/MD
#   be/VB
#   enough/RB
#   to/TO
#   carve/VB
#   up/RP
#   for/IN
#   both/DT
#   of/IN
#   us/PRP
#   ./.
#   -/:
#   You/PRP
#   see/VBP
#   that/IN
#   ,/,
#   right/RB
#   ?/.
#   -/:
#   I/PRP
#   do/VBP
#   ./.
#   So/RB
#   the/DT
#   strategy/NN
#   's/POS
#   changed/VBN
#   ./.
#   We/PRP
#   're/VBP
#   not/RB
#   being/VBG
#   kind/NN
#   and/CC
#   deferential/JJ
#   to/TO
#   the/DT
#   frontrunner/NN
#   ./.
#   We/PRP
#   're/VBP
#   acting/VBG
#   like/IN
#   the/DT
#   frontrunner/NN
#   ./.
#   We/PRP
#   're/VBP
#   not/RB
#   aiming/VBG
#   for/IN
#   the/DT
#   vice/NN
#   presidency/NN
#   ./.
#   We/PRP
#   're/VBP
#   aiming/VBG
#   for/IN
#   the/DT
#   presidency/NN
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   do/VBP
#   you/PRP
#   need/VBP
#   from/IN
#   me/PRP
#   ?/.
#   We/PRP
#   're/VBP
#   moving/VBG
#   up/RP
#   the/DT
#   announcement/NN
#   to/TO
#   Thursday/NNP
#   ./.
#   We/PRP
#   want/VBP
#   to/TO
#   take/VB
#   advantage/NN
#   of/IN
#   the/DT
#   momentum/NN
#   ./.
#   You/PRP
#   need/VBP
#   (PERSON Alicia/NNP)
#   ?/.
#   Yes/NNP
#   ,/,
#   much/RB
#   more/RBR
#   than/IN
#   we/PRP
#   originally/RB
#   agreed/VBD
#   ./.
#   Voters/NNS
#   need/VBP
#   to/TO
#   see/VB
#   these/DT
#   two/CD
#   together/RP
#   ./.
#   (PERSON Young/NNP)
#   ,/,
#   vibrant/JJ
#   ,/,
#   looking/VBG
#   toward/IN
#   the/DT
#   future/NN
#   ./.
#   (PERSON Jackie/NNP O/NNP)
#   to/TO
#   his/PRP$
#   (ORGANIZATION JFK/NNP)
#   ./.
#   We/PRP
#   need/VBP
#   to/TO
#   work/VB
#   together/RP
#   ,/,
#   (GPE Eli/NNP)
#   ./.
#   You/PRP
#   need/VBP
#   to/TO
#   trust/VB
#   me/PRP
#   ./.
#   And/CC
#   I/PRP
#   need/VBP
#   to/TO
#   trust/VB
#   you/PRP
#   ./.
#   Who/WP
#   's/VBZ
#   that/IN
#   ?/.
#   I/PRP
#   do/VBP
#   n't/RB
#   know/VB
#   ./.
#   (PERSON Silicon/NNP Valley/NNP)
#   lawyer/NN
#   ?/.
#   -/:
#   (GPE Hello/NNP)
#   ./.
#   Alice/NNP
#   Florrick/NNP
#   ,/,
#   yes/VBZ
#   ?/.
#   -/:
#   Yes/NNP
#   ./.
#   (PERSON Andrea/NNP Stevens/NNP)
#   ./.
#   It/PRP
#   's/VBZ
#   so/RB
#   nice/JJ
#   to/TO
#   meet/VB
#   you/PRP
#   ./.
#   I/PRP
#   was/VBD
#   told/JJ
#   you/PRP
#   were/VBD
#   the/DT
#   opposing/NN
#   counsel/NN
#   ./.
#   It/PRP
#   just/RB
#   makes/VBZ
#   it/PRP
#   so/RB
#   much/RB
#   more/RBR
#   exciting/VBG
#   when/WRB
#   you/PRP
#   respect/VBP
#   the/DT
#   opposition/NN
#   ,/,
#   do/VBP
#   n't/RB
#   you/PRP
#   think/VBP
#   ?/.
#   -/:
#   It/PRP
#   does/VBZ
#   ./.
#   -/:
#   (GPE Hello/NNP)
#   ./.
#   Hi/NNP
#   ./.
#   (PERSON Lucca/NNP Quinn/NNP)
#   ./.
#   Hi/NNP
#   ./.
#   I/PRP
#   love/VBP
#   your/PRP$
#   hair/NN
#   ./.
#   How/WRB
#   many/JJ
#   years/NNS
#   are/VBP
#   you/PRP
#   out/RP
#   of/IN
#   law/NN
#   school/NN
#   ,/,
#   (PERSON Lucca/NNP)
#   ?/.
#   A/DT
#   few/JJ
#   ./.
#   Well/NNP
#   ,/,
#   that/IN
#   's/POS
#   better/JJR
#   than/IN
#   less/JJR
#   than/IN
#   a/DT
#   few/JJ
#   ./.
#   All/DT
#   rise/NN
#   ./.
#   -/:
#   (GPE Oh/NNP)
#   ,/,
#   here/RB
#   we/PRP
#   go/VBP
#   ./.
#   -/:
#   (GPE Court/NNP)
#   is/VBZ
#   now/RB
#   in/IN
#   session/NN
#   ./.
#   (PERSON Lucca/NNP)
#   ,/,
#   if/IN
#   you/PRP
#   ever/RB
#   want/VBP
#   any/DT
#   advice/NN
#   ./.
#   (PERSON Good/NNP)
#   afternoon/NN
#   ./.
#   I/PRP
#   've/VBP
#   read/JJ
#   your/PRP$
#   preliminary/JJ
#   motions/NNS
#   ./.
#   I/PRP
#   would/MD
#   like/VB
#   to/TO
#   take/VB
#   up/RP
#   the/DT
#   ,/,
#   uh/NN
#   ,/,
#   jurisdictional/JJ
#   question/NN
#   ./.
#   Your/NNP
#   Honor/NNP
#   ,/,
#   the/DT
#   plaintiff/NN
#   lives/VBZ
#   in/IN
#   (GPE Chicago/NNP)
#   .../:
#   Whoa/NNP
#   ,/,
#   whoa/NN
#   ,/,
#   whoa/NN
#   ,/,
#   whoa/NN
#   !/.
#   Your/NNP
#   Honor/NNP
#   ,/,
#   I/PRP
#   was/VBD
#   warned/VBN
#   about/IN
#   (GPE Chicago/NNP)
#   courtrooms/NNS
#   ,/,
#   but/CC
#   I/PRP
#   did/VBD
#   n't/RB
#   think/VB
#   it/PRP
#   was/VBD
#   gon/JJ
#   na/NN
#   be/VB
#   about/IN
#   who/WP
#   shouted/VBN
#   the/DT
#   loudest/JJS
#   ./.
#   It/PRP
#   is/VBZ
#   n't/RB
#   ,/,
#   (GPE Counselor/NNP)
#   ./.
#   What/WP
#   do/VBP
#   you/PRP
#   have/VB
#   ?/.
#   Thank/NNP
#   you/PRP
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ./.
#   This/DT
#   is/VBZ
#   rank/NN
#   forum/NN
#   shopping/VBG
#   ./.
#   Mrs./NNP
#   Florrick/NNP
#   knows/VBZ
#   this/DT
#   case/NN
#   belongs/VBZ
#   in/IN
#   (GPE California/NNP)
#   ./.
#   Running/NNP
#   (PERSON Milk/NNP)
#   has/VBZ
#   no/DT
#   (GPE Chicago/NNP)
#   offices/NNS
#   ./.
#   And/CC
#   the/DT
#   lie/NN
#   detector/NN
#   test/NN
#   in/IN
#   question/NN
#   took/VBD
#   place/NN
#   in/IN
#   (GPE California/NNP)
#   ./.
#   (PERSON Kristen/NNP Balko/NNP)
#   lives/VBZ
#   in/IN
#   (GPE Chicago/NNP)
#   ./.
#   And/CC
#   thanks/NNS
#   to/TO
#   the/DT
#   cloud/NN
#   tax/NN
#   passed/VBD
#   by/IN
#   the/DT
#   (ORGANIZATION Chicago/NNP City/NNP Council/NNP)
#   ,/,
#   (PERSON Running/NNP Milk/NNP)
#   's/POS
#   offices/NNS
#   are/VBP
#   both/DT
#   in/IN
#   (GPE California/NNP)
#   and/CC
#   (GPE Illinois/NNP)
#   ./.
#   Yes/NNP
#   ,/,
#   but/CC
#   respectfully/RB
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ,/,
#   they/PRP
#   are/VBP
#   not/RB
#   physically/RB
#   in/IN
#   (GPE Illinois/NNP)
#   ./.
#   But/CC
#   as/IN
#   (ORGANIZATION Running/NNP Milk/NNP)
#   and/CC
#   its/PRP$
#   ilk/NN
#   have/VBP
#   constantly/RB
#   reminded/VBN
#   us/PRP
#   :/:
#   ``/``
#   (PERSON Brick/NNP)
#   and/CC
#   mortar/NN
#   are/VBP
#   things/NNS
#   of/IN
#   the/DT
#   past/JJ
#   ./.
#   The/DT
#   cloud/NN
#   is/VBZ
#   the/DT
#   future/NN
#   ./.
#   ''/''
#   Your/NNP
#   Honor/NNP
#   ,/,
#   so/RB
#   many/JJ
#   of/IN
#   our/PRP$
#   witnesses/NNS
#   will/MD
#   have/VB
#   to/TO
#   be/VB
#   flown/VBN
#   in/IN
#   from/IN
#   (GPE San/NNP Jose/NNP)
#   and/CC
#   that/IN
#   does/VBZ
#   n't/RB
#   .../:
#   And/CC
#   so/RB
#   many/JJ
#   of/IN
#   our/PRP$
#   witnesses/NNS
#   will/MD
#   have/VB
#   -/:
#   to/TO
#   be/VB
#   flown/VBN
#   in/IN
#   from/IN
#   (GPE Chicago/NNP)
#   .../:
#   -/:
#   Your/NNP
#   Honor/NNP
#   ,/,
#   to/TO
#   refute/VB
#   these/DT
#   .../:
#   Thank/NNP
#   you/PRP
#   ./.
#   But/CC
#   as/IN
#   Ms./NNP
#   (PERSON Stevens/NNP)
#   pointed/VBD
#   out/RP
#   ,/,
#   this/DT
#   should/MD
#   n't/RB
#   be/VB
#   about/IN
#   who/WP
#   shouts/NNS
#   the/DT
#   loudest/JJS
#   ./.
#   (PERSON Motion/NNP)
#   is/VBZ
#   denied/VBN
#   ./.
#   We/PRP
#   'll/MD
#   hear/VB
#   the/DT
#   case/NN
#   here/RB
#   ./.
#   Please/NNP
#   have/VBP
#   the/DT
#   Running/NNP
#   Milk/NNP
#   software/NN
#   spec/NN
#   sent/NN
#   to/TO
#   me/PRP
#   by/IN
#   end/NN
#   of/IN
#   day/NN
#   ,/,
#   thank/NN
#   you/PRP
#   ./.
#   Just/RB
#   the/DT
#   first/JJ
#   skirmish/NN
#   ./.
#   -/:
#   (PERSON Peter/NNP)
#   wants/VBZ
#   to/TO
#   be/VB
#   president/NN
#   ./.
#   -/:
#   (PERSON Excuse/NNP)
#   me/PRP
#   ?/.
#   (PERSON Peter/NNP)
#   thinks/VBZ
#   he/PRP
#   can/MD
#   be/VB
#   president/NN
#   ./.
#   I/PRP
#   need/VBP
#   a/DT
#   drink/NN
#   ./.
#   Do/NNP
#   you/PRP
#   want/VB
#   one/CD
#   ?/.
#   No/DT
#   ,/,
#   I/PRP
#   need/VBP
#   to/TO
#   go/VB
#   ./.
#   They/PRP
#   moved/VBD
#   the/DT
#   announcement/NN
#   up/RP
#   to/TO
#   Thursday/NNP
#   ./.
#   You/PRP
#   need/VBP
#   to/TO
#   be/VB
#   in/IN
#   (GPE Springfield/NNP)
#   ./.
#   I/PRP
#   wrote/VBD
#   you/PRP
#   a/DT
#   speech/NN
#   ;/:
#   very/RB
#   (PERSON Michelle/NNP Obama/NNP)
#   ./.
#   -/:
#   What/WP
#   time/NN
#   Thursday/NNP
#   ?/.
#   -/:
#   3:00/CD
#   p.m/RB
#   ./.
#   They/PRP
#   'll/MD
#   need/VB
#   us/PRP
#   more/JJR
#   than/IN
#   usual/JJ
#   ./.
#   They/PRP
#   keep/VBP
#   mixing/VBG
#   their/PRP$
#   metaphors/NNS
#   ./.
#   You/PRP
#   're/VBP
#   either/DT
#   (PERSON Michelle/NNP Obama/NNP)
#   or/CC
#   (PERSON Jackie/NNP O/NNP)
#   ./.
#   Do/NNP
#   you/PRP
#   ever/RB
#   wonder/JJR
#   why/WRB
#   I/PRP
#   'm/VBP
#   hearing/VBG
#   this/DT
#   from/IN
#   you/PRP
#   and/CC
#   not/RB
#   (PERSON Peter/NNP)
#   ?/.
#   What/WP
#   ?/.
#   No/DT
#   ./.
#   What/WP
#   do/VBP
#   you/PRP
#   mean/VB
#   ?/.
#   Well/NNP
#   ,/,
#   I/PRP
#   'm/VBP
#   hearing/VBG
#   that/IN
#   (PERSON Peter/NNP)
#   truly/RB
#   is/VBZ
#   running/VBG
#   for/IN
#   president/NN
#   and/CC
#   that/IN
#   I/PRP
#   might/MD
#   be/VB
#   (PERSON First/NNP Lady/NNP)
#   from/IN
#   his/PRP$
#   campaign/NN
#   manager/NN
#   ./.
#   I/PRP
#   am/VBP
#   not/RB
#   his/PRP$
#   campaign/NN
#   manager/NN
#   ./.
#   You/PRP
#   think/VBP
#   he/PRP
#   has/VBZ
#   a/DT
#   chance/NN
#   ?/.
#   I/PRP
#   do/VBP
#   n't/RB
#   know/VB
#   ./.
#   I/PRP
#   thought/VBD
#   (PERSON Trump/NNP)
#   would/MD
#   self-destruct/VB
#   ,/,
#   so/RB
#   what/WP
#   do/VBP
#   I/PRP
#   know/VB
#   ?/.
#   Primaries/NNPS
#   are/VBP
#   their/PRP$
#   own/JJ
#   insanity/NN
#   ./.
#   What/WP
#   are/VBP
#   you/PRP
#   making/VBG
#   ?/.
#   A/DT
#   margarita/NN
#   ./.
#   (PERSON Tequila/NNP)
#   ,/,
#   triple/RB
#   sec/JJ
#   ./.
#   Huh/NNP
#   ./.
#   -/:
#   You/PRP
#   judging/VBG
#   me/PRP
#   ?/.
#   -/:
#   No/DT
#   ./.
#   That/DT
#   sounded/VBD
#   like/IN
#   a/DT
#   judgmental/JJ
#   huh/NN
#   ./.
#   No/DT
#   ./.
#   You/PRP
#   get/VB
#   as/IN
#   sloppy/JJ
#   drunk/NN
#   as/IN
#   you/PRP
#   want/VBP
#   to/TO
#   ./.
#   So/RB
#   ,/,
#   what/WDT
#   do/VBP
#   they/PRP
#   want/VBP
#   me/PRP
#   to/TO
#   do/VB
#   ?/.
#   Be/VB
#   involved/VBN
#   ./.
#   Go/NNP
#   on/IN
#   Thursday/NNP
#   ./.
#   Give/NNP
#   a/DT
#   good/JJ
#   speech/NN
#   ./.
#   (PERSON Look/NNP First/NNP)
#   Lady-like/NNP
#   ./.
#   I/PRP
#   got/VBD
#   (PERSON Frank/NNP Landau/NNP)
#   to/TO
#   introduce/VB
#   you/PRP
#   ./.
#   It/PRP
#   's/VBZ
#   not/RB
#   bad/JJ
#   having/NN
#   the/DT
#   head/NN
#   of/IN
#   the/DT
#   (ORGANIZATION Democratic/JJ)
#   committee/NN
#   say/NN
#   nice/NN
#   things/NNS
#   about/IN
#   you/PRP
#   ./.
#   What/WP
#   are/VBP
#   you/PRP
#   doing/VBG
#   ,/,
#   (PERSON Eli/NNP)
#   ?/.
#   This/DT
#   does/VBZ
#   n't/RB
#   sound/VB
#   like/IN
#   you/PRP
#   ./.
#   Sure/NNP
#   it/PRP
#   does/VBZ
#   ./.
#   This/DT
#   is/VBZ
#   what/WP
#   I/PRP
#   sound/VBP
#   like/IN
#   ./.
#   No/DT
#   ,/,
#   no/DT
#   ,/,
#   no/DT
#   ,/,
#   no/DT
#   ./.
#   You/PRP
#   're/VBP
#   scheming/VBG
#   something/NN
#   here/RB
#   ./.
#   Cheers/NNS
#   ./.
#   Hey/NNP
#   ,/,
#   I/PRP
#   've/VBP
#   got/VBN
#   some/DT
#   good/JJ
#   news/NN
#   and/CC
#   I/PRP
#   got/VBD
#   some/DT
#   bad/JJ
#   news/NN
#   .../:
#   which/WDT
#   do/VBP
#   you/PRP
#   want/VB
#   first/JJ
#   ?/.
#   -/:
#   (GPE Bad/JJ)
#   ./.
#   -/:
#   (GPE Good/NNP)
#   ./.
#   Running/NNP
#   (PERSON Milk/NNP)
#   's/POS
#   HR/NNP
#   team/NN
#   definitely/RB
#   verified/VBN
#   -/:
#   (PERSON Kristen/NNP)
#   lied/VBD
#   on/IN
#   her/PRP$
#   resume/NN
#   ./.
#   -/:
#   (GPE Damn/NNP)
#   ./.
#   -/:
#   So/RB
#   we/PRP
#   have/VBP
#   no/DT
#   case/NN
#   ./.
#   -/:
#   What/WP
#   's/VBZ
#   the/DT
#   good/JJ
#   news/NN
#   ?/.
#   I/PRP
#   do/VBP
#   n't/RB
#   think/VB
#   there/EX
#   was/VBD
#   a/DT
#   theft/NN
#   at/IN
#   (FACILITY Running/NNP Milk/NNP)
#   ./.
#   What/WP
#   do/VBP
#   you/PRP
#   mean/VB
#   ?/.
#   A/DT
#   firm/NN
#   like/IN
#   (ORGANIZATION Running/NNP Milk/NNP)
#   is/VBZ
#   required/VBN
#   to/TO
#   notify/VB
#   their/PRP$
#   customers/NNS
#   of/IN
#   any/DT
#   breach/NN
#   ;/:
#   they/PRP
#   did/VBD
#   n't/RB
#   ./.
#   (GPE California/NNP)
#   attorney/NN
#   general/NN
#   's/POS
#   got/NN
#   no/DT
#   record/NN
#   of/IN
#   any/DT
#   breach/NN
#   at/IN
#   (FACILITY Running/NNP Milk/NNP)
#   ./.
#   So/RB
#   they/PRP
#   had/VBD
#   no/DT
#   reason/NN
#   to/TO
#   polygraph/VB
#   ./.
#   Right/RB
#   ,/,
#   fruit/NN
#   of/IN
#   the/DT
#   poisonous/JJ
#   tree/NN
#   ./.
#   Why/WRB
#   'd/JJ
#   you/PRP
#   punch/VBP
#   that/IN
#   judge/NN
#   ?/.
#   I/PRP
#   was/VBD
#   angry/JJ
#   ./.
#   Why/WRB
#   were/VBD
#   you/PRP
#   angry/JJ
#   ?/.
#   Do/NNP
#   n't/RB
#   you/PRP
#   get/VB
#   angry/JJ
#   ?/.
#   I/PRP
#   do/VBP
#   ,/,
#   but/CC
#   I/PRP
#   do/VBP
#   n't/RB
#   punch/VB
#   people/NNS
#   ./.
#   Maybe/NNP
#   you/PRP
#   should/MD
#   start/VB
#   ./.
#   As/IN
#   you/PRP
#   can/MD
#   see/VB
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ,/,
#   (PERSON Running/NNP Milk/NNP)
#   never/RB
#   suffered/VBD
#   a/DT
#   security/NN
#   breach/NN
#   ,/,
#   and/CC
#   since/IN
#   that/DT
#   was/VBD
#   the/DT
#   only/JJ
#   legal/JJ
#   justification/NN
#   for/IN
#   polygraphing/NN
#   our/PRP$
#   client/NN
#   ,/,
#   -/:
#   that/IN
#   polygraph/NN
#   must/MD
#   be/VB
#   thrown/VBN
#   out/RP
#   ./.
#   -/:
#   Is/VBZ
#   this/DT
#   true/JJ
#   ?/.
#   Can/NNP
#   you/PRP
#   give/VBP
#   me/PRP
#   one/CD
#   second/JJ
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ?/.
#   As/NNP
#   you/PRP
#   requested/VBD
#   ,/,
#   uh/NN
#   ,/,
#   the/DT
#   (ORGANIZATION CEO/NNP)
#   of/IN
#   Running/NNP
#   (PERSON Milk/NNP)
#   flew/VBD
#   in/IN
#   a/DT
#   great/JJ
#   personal/JJ
#   expense/NN
#   ./.
#   I/PRP
#   'm/VBP
#   honored/VBN
#   ./.
#   Without/IN
#   admitting/VBG
#   to/TO
#   any/DT
#   wrongdoing/NN
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ,/,
#   (PERSON Running/NNP Milk/NNP)
#   generously/RB
#   agrees/VBZ
#   to/TO
#   rehire/VB
#   the/DT
#   plaintiff/NN
#   at/IN
#   her/PRP$
#   original/JJ
#   salary/NN
#   ./.
#   We/PRP
#   just/RB
#   want/VBP
#   this/DT
#   to/TO
#   be/VB
#   over/IN
#   ./.
#   -/:
#   Really/RB
#   ?/.
#   Since/IN
#   when/WRB
#   ?/.
#   -/:
#   Since/IN
#   an/DT
#   hour/NN
#   ago/IN
#   ./.
#   We/PRP
#   ask/VBP
#   that/IN
#   this/DT
#   suit/NN
#   be/VB
#   dismissed/VBN
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ./.
#   Your/PRP$
#   Honor/NNP
#   ,/,
#   if/IN
#   our/PRP$
#   client/NN
#   is/VBZ
#   rehired/VBN
#   ,/,
#   she/PRP
#   ca/MD
#   n't/RB
#   be/VB
#   subjected/VBN
#   to/TO
#   a/DT
#   new/JJ
#   polygraph/NN
#   ,/,
#   is/VBZ
#   that/IN
#   correct/JJ
#   ?/.
#   Yes/NNP
#   ,/,
#   private/JJ
#   employers/NNS
#   are/VBP
#   barred/VBN
#   from/IN
#   making/VBG
#   polygraphs/NNS
#   a/DT
#   condition/NN
#   of/IN
#   employment/NN
#   ./.
#   May/NNP
#   we/PRP
#   have/VBP
#   a/DT
#   ruling/NN
#   on/IN
#   that/DT
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ?/.
#   Um/NNP
#   ,/,
#   can/MD
#   .../:
#   I'm-I/-NONE-
#   'm/JJ
#   sorry/NN
#   ,/,
#   can/MD
#   I/PRP
#   just/RB
#   have/VBP
#   one/CD
#   more/RBR
#   second/JJ
#   ,/,
#   (PERSON Your/NNP Honor/NNP)
#   ?/.
#   Actually/NNP
#   ,/,
#   polygraphs/VBZ
#   may/MD
#   be/VB
#   applied/VBN
#   to/TO
#   employees/NNS
#   engaged/VBN
#   in/IN
#   counterintelligence/NN
#   or/CC
#   national/JJ
#   security/NN
#   functions/NNS
#   ,/,
#   pursuant/JJ
#   to/TO
#   a/DT
#   contract/NN
#   with/IN
#   the/DT
#   federal/JJ
#   government/NN
#   ./.
#   Your/NNP
#   Honor/NNP
#   ,/,
#   our/PRP$
#   client/NN
#   has/VBZ
#   no/DT
#   connection/NN
#   with/IN
#   national/JJ
#   security/NN
#   ./.
#   And/CC
#   again/RB
#   I/PRP
#   ask/VBP
#   for/IN
#   a/DT
#   ruling/NN
#   ./.
#   These/DT
#   contracts/NNS
#   show/VBP
#   that/IN
#   (PERSON Running/NNP Milk/NNP)
#   has/VBZ
#   ongoing/VBG
#   accounts/NNS
#   with/IN
#   the/DT
#   government/NN
#   ./.
#   This/DT
#   makes/VBZ
#   no/DT
#   sense/NN
#   ./.
#   If/IN
#   these/DT
#   contracts/NNS
#   were/VBD
#   the/DT
#   reason/NN
#   for/IN
#   these/DT
#   polygraph/NN
#   tests/NNS
#   ,/,
#   then/RB
#   why/WRB
#   create/VB
#   the/DT
#   fiction/NN
#   of/IN
#   a/DT
#   security/NN
#   breach/NN
#   ?/.
#   Are/NNP
#   we/PRP
#   really/RB
#   wondering/VBG
#   why/WRB
#   the/DT
#   (ORGANIZATION National/NNP)
#   Security/NNP
#   Agency/NNP
#   might/MD
#   have/VB
#   a/DT
#   need/NN
#   for/IN
#   secrecy/NN
#   ?/.
#   Your/NNP
#   Honor/NNP
#   ,/,
#   the/DT
#   defendant/NN
#   just/RB
#   plans/VBZ
#   to/TO
#   rehire/VB
#   our/PRP$
#   client/NN
#   so/IN
#   they/PRP
#   can/MD
#   fire/VB
#   her/PRP
#   again/RB
#   ./.
#   Yes/NNS
#   ,/,
#   but/CC
#   legally/RB
#   ./.
#   These/DT
#   contracts/NNS
#   appear/VBP
#   in/IN
#   order/NN
#   ./.
#   (PERSON Before/NNP Miss/NNP Balko/NNP)
#   starts/VBZ
#   work/NN
#   again/RB
#   ,/,
#   she/PRP
#   'll/MD
#   need/VB
#   to/TO
#   submit/VB
#   to/TO
#   a/DT
#   polygraph/NN
#   ./.
#   Your/NNP
#   Honor/NNP
#   ./.
#   I/PRP
#   do/VBP
#   n't/RB
#   have/VB
#   time/NN
#   for/IN
#   this/DT
#   ,/,
#   (GPE Eli/NNP)
#   ./.
#   Even/RB
#   for/IN
#   a/DT
#   friend/NN
#   ?/.
#   If/IN
#   you/PRP
#   're/VBP
#   wearing/VBG
#   a/DT
#   wire/NN
#   ,/,
#   you/PRP
#   have/VBP
#   to/TO
#   tell/VB
#   me/PRP
#   ,/,
#   or/CC
#   it/PRP
#   'll/MD
#   be/VB
#   thrown/VBN
#   out/RP
#   in/IN
#   court/NN
#   ./.
#   I/PRP
#   am/VBP
#   not/RB
#   wearing/VBG
#   a/DT
#   wire/NN
#   ./.
#   I/PRP
#   need/VBP
#   your/PRP$
#   help/NN
#   ./.
#   I/PRP
#   would/MD
#   never/RB
#   have/VB
#   taken/VBN
#   that/IN
#   bribe/NN
#   ./.
#   I/PRP
#   did/VBD
#   n't/RB
#   need/VBN
#   you/PRP
#   to/TO
#   warn/VB
#   me/PRP
#   ./.
#   But/CC
#   I/PRP
#   did/VBD
#   warn/VB
#   you/PRP
#   ./.
#   What/WP
#   ?/.
#   What/WP
#   do/VBP
#   you/PRP
#   need/VBP
#   ?/.
#   Information/NNP
#   on/IN
#   (PERSON Frank/NNP Landau/NNP)
#   and/CC
#   his/PRP$
#   manipulation/NN
#   of/IN
#   voting/NN
#   machines/NNS
#   in/IN
#   the/DT
#   last/JJ
#   election/NN
#   ./.
#   -/:
#   No/DT
#   ,/,
#   I/PRP
#   wo/MD
#   n't/RB
#   betray/VB
#   him/PRP
#   ./.
#   -/:
#   He/PRP
#   wo/MD
#   n't/RB
#   know/VB
#   it/PRP
#   's/VBZ
#   you/PRP
#   ./.
#   I/PRP
#   just/RB
#   need/VBP
#   the/DT
#   proof/NN
#   from/IN
#   you/PRP
#   ,/,
#   and/CC
#   I/PRP
#   'll/MD
#   do/VB
#   the/DT
#   rest/NN
#   ./.
#   What/WP
#   are/VBP
#   you/PRP
#   up/IN
#   to/TO
#   ?/.
#   (/:
#   .../:
#   )/:)

# %%
len(text)
# Out:
# 12175
