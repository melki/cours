# %%
from arftools import *

import csv


import pandas as pd

# %matplotlib inline

# %%
df1=pd.read_csv('data/two_gaussians.csv',sep=';')
x1=df1[['x1','x2']].values
y1=df1['y'].values
plot_data(x1,y1)

# %%
df2=pd.read_csv('data/four_gaussians.csv',sep=';')
x2=df2[['x1','x2']].values
y2=df2['y'].values
plot_data(x2,y2)

# %%
df3=pd.read_csv('data/echequier.csv',sep=';')
x3=df3[['x1','x2']].values
y3=df3['y'].values
plot_data(x3,y3)

# %%
df4=pd.read_csv('data/concentric.csv',sep=';')
x4=df4[['x1','x2']].values
y4=df4['y'].values
plot_data(x4,y4)

# %%
df5=pd.read_csv('data/concentric2.csv',sep=';')
x5=df5[['x1','x2']].values
y5=df5['y'].values
plot_data(x5,y5)
